# %%
# !pip install pyproj
# !pip install -U numpy==1.26.4
# !pip install transformers
# !pip install -U accelerate
# !pip install pandas
# !pip install PyPDF2
# !pip install NLTK
# !pip install editdistance
# !pip install paramiko
# !pip install func_timeout

import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# Requirement already satisfied: pyproj in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (3.6.1)
# Requirement already satisfied: certifi in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from pyproj) (2024.7.4)
# Requirement already satisfied: numpy==1.26.4 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (1.26.4)
# Requirement already satisfied: transformers in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (4.44.1)
# Requirement already satisfied: filelock in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from transformers) (0.24.6)
# Requirement already satisfied: numpy>=1.17 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from transformers) (2024.7.24)
# Requirement already satisfied: requests in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from transformers) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from requests->transformers) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from requests->transformers) (2024.7.4)
# Requirement already satisfied: accelerate in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (0.33.0)
# Requirement already satisfied: numpy<2.0.0,>=1.17 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from accelerate) (24.1)
# Requirement already satisfied: psutil in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: pyyaml in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from accelerate) (2.4.0)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from accelerate) (0.24.6)
# Requirement already satisfied: safetensors>=0.3.1 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from accelerate) (0.4.4)
# Requirement already satisfied: filelock in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from huggingface-hub>=0.21.0->accelerate) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from huggingface-hub>=0.21.0->accelerate) (2024.6.1)
# Requirement already satisfied: requests in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.11.0)
# Requirement already satisfied: sympy in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2024.7.4)
# Requirement already satisfied: mpmath>=0.19 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: pandas in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: PyPDF2 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (3.0.1)
# Requirement already satisfied: NLTK in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (3.9.1)
# Requirement already satisfied: click in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from NLTK) (8.1.7)
# Requirement already satisfied: joblib in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from NLTK) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from NLTK) (2024.7.24)
# Requirement already satisfied: tqdm in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from NLTK) (4.66.5)
# Requirement already satisfied: editdistance in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (0.8.1)
# Requirement already satisfied: paramiko in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (3.4.1)
# Requirement already satisfied: bcrypt>=3.2 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from paramiko) (4.2.0)
# Requirement already satisfied: cryptography>=3.3 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from paramiko) (43.0.0)
# Requirement already satisfied: pynacl>=1.5 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from paramiko) (1.5.0)
# Requirement already satisfied: cffi>=1.12 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from cryptography>=3.3->paramiko) (1.16.0)
# Requirement already satisfied: pycparser in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=3.3->paramiko) (2.21)
# Requirement already satisfied: func_timeout in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (4.3.5)
# [nltk_data] Downloading package punkt to /home/alex/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/alex/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# import libraries
import urllib.request
import requests
import json
from pyproj import Transformer
import os
import time
import sys
from datetime import datetime
#from lxml import etree
from xml.etree import ElementTree as ET
import logging
import nltk

# import common functions
sys.path.insert(1, '../')
import common

# set name of module, to fetch info from config
module_name = "dans"

# %%
# get info from config file
config = common.get_config()

# set up logging
log_location = config['data_source'][module_name]['harvest_log_location']
now = datetime.now()
date = now.strftime("%Y-%m-%d")
logfile = f"{log_location}harvest-log-{module_name}-{date}.log"
logging.basicConfig(level=logging.DEBUG, filename=logfile, filemode="a+",
                format="%(asctime)-15s %(levelname)-8s %(message)s")

# log config info        
last_indexed_date = config['data_source'][module_name]['last_indexed_date']
print(f'last_indexed_date: {last_indexed_date}')

endpoint_url = config['data_source'][module_name]['endpoint_url']
print(f'endpoint_url: {endpoint_url}')

pdf_folder = config['data_source'][module_name]['pdf_folder']
print(f'pdf_folder: {pdf_folder}')

json_folder = config['data_source'][module_name]['json_folder']
print(f'json_folder: {json_folder}')

html_folder = config['data_source'][module_name]['html_folder']
print(f'html_folder: {html_folder}')

language = config['data_source'][module_name]['language']
print(f'language: {language}')

bert_model = config['bert_models'][language]
print(f'bert_model: {bert_model}')
# Out:
# last_indexed_date: 2024-08-26T09:02:42Z
# endpoint_url: https://archaeology.datastations.nl/api/
# pdf_folder: /media/alex/Data/agnes_data/dans/pdf/
# json_folder: /media/alex/Data/agnes_data/dans/json/
# html_folder: /media/alex/Data/agnes_data/dans/html/
# language: dutch
# bert_model: /media/alex/Data/agnes_models/ArcheoBERTje-NER

# %%
#API settings
index_datetimestring = str(datetime.now().strftime("%Y-%m-%dT%H:%M:%S"))
providerName = 'Data_Station_Archaeology'
api_url = endpoint_url + 'search'
meta_url = endpoint_url + 'datasets/export'
content_url = endpoint_url + 'access/datafile/'
headers = {'Origin': 'http://agnessearch.nl',
           'Access-Control-Request-Method': 'GET',
           'httpAccept': 'application/json',
           'User-Agent': 'python-requests/2.18.1',
           'From': 'a.brandsen@arch.leidenuniv.nl (EXALT)'  
          }
page_length = 100  # size of the metadata chunks
datesort = "dateSort:["+str(last_indexed_date)+" TO "+index_datetimestring+"Z]"

# %%
params = {
            'X-Dataverse-Key': '0450fc54-e0e7-4692-b82c-e196eed69b12',  # personal API key valid till 01.05.2024
            'start': 0,                                                 # start of iteration
            'per_page': page_length,                                    # results in pages of n datasets (max. 1000)
            'type': 'dataset',
            'fq': 'publicationStatus:Published',                        # no Draft datasets
            'fq': datesort,  # everything from selected date onwards
            #'q': 'benedenberg',                                          # query (*) within archaeology.datastation.nl
            #'q': 'authorName:(schinkel AND fokkens)',                    # AND 
            #'q': 'authorName:(schinkel+OR+fokkens+OR+fontijn)',          # OR
            #'q': 'dsPublicationDate:2023',
            'q': 'dsPublicationDate:(2022 OR 2023 OR 2024 OR 2025 OR 2026 OR 2027 OR 2028 OR 2029)', # year of publication
            #'q': 'dsPublicationDate:(1930 OR 1950 OR 1951 OR 1952 OR 1953 OR 1954 OR 1955 OR 1956 OR 1958 OR \
            #          1959 OR 1961 OR 1962 OR 1963 OR 1964 OR 1965 OR 1966 OR 1967 OR 1968 OR 1969 \
            #          OR 1970 OR 1971 OR 1972 OR 1973 OR 1974 OR 1975 OR 1976 OR 1977 OR 1978 OR 1979 \
            #          OR 1980 OR 1981 OR 1982 OR 1983 OR 1984 OR 1985 OR 1986 OR 1987 OR 1988 OR 1989 \
            #          OR 1990 OR 1991 OR 1992 OR 1993 OR 1994 OR 1995 OR 1996 OR 1997 OR 1998 OR 1999 \
            #          OR 2000 OR 2001 OR 2002 OR 2003 OR 2004 OR 2005)',
}

# %%
# Create a requests Session
session = requests.Session()
# Set the header options, zoals 'application/json'
session.headers.update(headers)

# %%
i = 0
# Make a request and store the response
try:
    response = session.get(api_url, params=params)
    response.raise_for_status()                 # Raise error in case of failure 
except requests.exceptions.HTTPError as httpErr: 
    print ("HTTP Error:",httpErr) 
except requests.exceptions.ConnectionError as connErr: 
    print ("Error Connecting:",connErr) 
except requests.exceptions.Timeout as timeOutErr: 
    print ("Timeout Error:",timeOutErr) 
except requests.exceptions.RequestException as reqErr: 
    print ("Something Else:",reqErr)

# %%
if response.status_code == requests.codes.ok:
    
    if response:

        data = response.json()
            
        response_length = data['data']['total_count']
        print('Datasets found: '+ str(response_length))
            
        dsets = data['data']['items']

        # Fetch all the other pages of results
        page = 1
        while (page*page_length+1) <= response_length:
            params['start'] = (page*page_length)
            #print (page, params['start'])

            # GET the next page of dataset metadata
            next_response = session.get(api_url, params=params)
            if next_response.status_code == requests.codes.ok:
             if next_response:
                 next_data = next_response.json()
                 next_dsets = next_data['data']['items']
        
                 # add the data from the next page to the data we collected
                 dsets = dsets + next_dsets
            page = page + 1
            #time.sleep(1)                 # being kind to the API server

    else:
        print ('Empty result')
else:
        print ('Web connection Error')
# Out:
# Datasets found: 8035
# Saved: 0

# %%
import pickle 
  
# Open a file and use dump() 
with open('dsets-TEMP-23-2-25.pkl', 'wb') as file: 
      
    # A new file will be created 
    pickle.dump(dsets, file)

# %%
import pickle

# Open the file in binary mode 
with open('dsets-TEMP.pkl', 'rb') as file: 
      
    # Call load method to deserialze 
    dsets = pickle.load(file)

# %%
#processing the metadata of the datasets
if dsets:

    # sort dsets by published date
    date_sorted_dsets = sorted(dsets, key=lambda d: d['published_at'])
    
    print ('Processing: ' + str(len(date_sorted_dsets)) + ' datasets')
    for dset in date_sorted_dsets:

        # skip to specific dataset TEMP
        if dset['global_id'] != 'doi:10.17026/AR/5VSVUK':
            continue
        
        #print(json.dumps(dset, indent=4, sort_keys=False))  
        print('--------------------------------------------')
        print('Processing dataset: '+dset['global_id'])
        
        # get extended metadata
        if dset['global_id']:
            dataset_doi = dset['global_id']
            meta_params = { 'X-Dataverse-Key': '0450fc54-e0e7-4692-b82c-e196eed69b12',
                            'exporter': 'dataverse_json',                             # metadata format
                            'httpAccept': 'application/json',
                            'persistentId': dataset_doi}
            meta_response = requests.get(meta_url, params=meta_params)                # request dataset metadata
            
            if meta_response.status_code == requests.codes.ok:
                if meta_response:
                    metadata = meta_response.json()

                    #print(json.dumps(metadata, indent=4, sort_keys=False)) 
                    #exit()

                    metadataBlocks = metadata['datasetVersion']['metadataBlocks']
                    
                    files = metadata['datasetVersion']['files']
                    for file in files:
                        #print(file)
                        dataFile = file['dataFile']
                        if dataFile['contentType'] == 'application/pdf':

                            print('Processing file: '+dataFile['filename'])

                            # generate document dictionary
                            output_document = {}
                            output_document['source'] = module_name
                            output_document['file_name'] = common.cleanFileName(dataFile['filename'])
                            output_document['description'] = dset['description']
                            output_document['title'] = dset['name']
                            output_document['creators'] = dset['authors']
                            output_document['publisher'] = dset['publisher']
                            output_document['createdAt'] = dset['published_at'][:10]
                            
                            identifiers = {
                                'DOI':dset['global_id'],
                                'url':dset['url'],
                                'dans_dataset_version_id': dset['versionId']
                            }
                            if 'dansArchaeologyMetadata' in metadataBlocks:
                                for thing in metadataBlocks['dansArchaeologyMetadata']['fields']:
                                    if thing['typeName'] == 'dansArchisZaakId':
                                        identifiers['dansArchisZaakId'] = thing['value']
                            if 'dansDataVaultMetadata' in metadataBlocks:
                                for thing in metadataBlocks['dansDataVaultMetadata']['fields']:
                                    identifiers[thing['typeName']] = thing['value']
                            output_document['identifiers'] = identifiers

                            if 'citation' in metadataBlocks:
                                for thing in metadataBlocks['citation']['fields']:
                                    if thing['typeName'] == 'language':
                                        output_document['language'] = thing['value']
                            
                            # check dag/week rapport etc, so we can filter these out in ES
                            rapportList = ['dagrapport' , 'dag_rapport' , 'weekrapport' , 'week_rapport' , 'weekverslag' , 'week_verslag' , 'logboek']
                            pvaList = ['draaiboek' , 'plan_van_aanpak' , 'pva']
                            pveList = ['programma_van_eisen' , 'pve']
                            omnList = ['onderzoeksmeldingsnummer' , 'onderzoeksmeldings_nummer' , 'onderzoeks_meldings_nummer']
                            if any(word in dataFile['filename'].lower() for word in rapportList):
                                output_document['file_type'] = 'dag_week_rapport'
                            elif any(word in dataFile['filename'].lower() for word in pvaList):
                                output_document['file_type'] = 'plan_van_aanpak'
                            elif any(word in dataFile['filename'].lower() for word in pveList):
                                output_document['file_type'] = 'programma_van_eisen'
                            elif any(word in dataFile['filename'].lower() for word in omnList):
                                output_document['file_type'] = 'onderzoeksmeldingsnummer'
                            else:
                                output_document['file_type'] = 'report'
                            
                            
                            # coordinates 
                            coordX = False
                            coordY = False

                            if 'dansTemporalSpatial' in metadataBlocks:
                                for thing in metadataBlocks['dansTemporalSpatial']['fields']:
                                    if thing['typeName'] == 'dansSpatialBox':
                                        # bounding box
                                        #print(thing)
                                        totalX = 0
                                        totalY = 0
                                        for box in thing['value']:
                                            #print(box)
                                            # some datasets are missing 1 of the boundin
                                            if 'dansSpatialBoxEast' in box and 'dansSpatialBoxWest' in box and 'dansSpatialBoxSouth' in box and 'dansSpatialBoxNorth' in box and :
                                                totalX += (float(box['dansSpatialBoxEast']['value']) + float(box['dansSpatialBoxWest']['value'])) / 2 
                                                totalY += (float(box['dansSpatialBoxSouth']['value']) + float(box['dansSpatialBoxNorth']['value'])) / 2
                                        coordX = totalX / len(thing['value'])
                                        coordY = totalY / len(thing['value'])
                                        
                                    elif thing['typeName'] == 'dansSpatialPoint':
                                        # point
                                        #print(thing['value'])
                                        totalX = 0
                                        totalY = 0
                                        for point in thing['value']:
                                            #print(point)
                                            if 'dansSpatialPointX' in box:
                                                totalX += float(point['dansSpatialPointX']['value'])
                                                totalY += float(point['dansSpatialPointY']['value'])
                                        coordX = totalX / len(thing['value'])
                                        coordY = totalY / len(thing['value'])
                                       
                            
                            if not coordX and not coordY:
                                # no coordinates, try geocoding the location(s)
                                if 'dansTemporalSpatial' in metadataBlocks:
                                    for thing in metadataBlocks['dansTemporalSpatial']['fields']:    
                                        if thing['typeName'] == 'dansSpatialCoverageText':
                                            #print('doing GEOCODING')
                                            try:
                                                locations = thing['value']
                                                query = ''
                                                if type(locations) is list:
                                                    for location in locations:
                                                        query += location + ', ' 
                                                url = f"https://nominatim.openstreetmap.org/search?q={urllib.parse.quote(query)}&format=geojson&limit=1"
                                                #print(url)
                                                response = urllib.request.urlopen(url)
                                                data = json.loads(response.read())
                                                if len(data['features']): # if results
                                                    lat = data['features'][0]['geometry']['coordinates'][0]
                                                    lon = data['features'][0]['geometry']['coordinates'][1]
                                                    output_document['location'] = {'lat':lat,'lon':lon}
                                            except Exception as error:
                                                print('geocoding error')
                                                print(error)                                

                            if coordX and coordY:
                                output_document['coordX'] = coordX
                                output_document['coordY'] = coordY
                                #convert to lat lon
                                try:
                                    lat, lon = common.rd2wgs(coordX,coordY)
                                    output_document['location'] = {'lat':lat,'lon':lon}
                                except:
                                    print('error converting coordinates from rd to wgs for DOI '+dset['global_id'])

                            
                            # object file download (Open Access)
                            if dataFile['id'] and not file['restricted']:

                                # check for embargo
                                present = datetime.now()                                     
                                embargo = datetime.now()
                                
                                if 'embargo' in file.keys():
                                    embargo = datetime.strptime(filemeta['embargo'], "%Y-%m-%d")
                                
                                if not embargo.date() > present.date(): 

                                    # set document identifier
                                    doc_id = f"{dset['versionId']}_{common.cleanFileName(dataFile['filename'].replace('.pdf',''))}"
                                    
                                    print(f"doc_id:{doc_id}")

                                    # # TEMP if already downloaded, skip
                                    # output_location = f"{pdf_folder}{dset['versionId']}_{common.cleanFileName(dataFile['filename'])}"
                                    # if os.path.isfile(output_location):
                                    #     print('already downloaded, SKIPPING')
                                    #     continue

                                    # sometimes get download error, so try and continue if error
                                    try:
                                        # download pdf
                                        file_url = content_url + str(dataFile['id'] ) 
                                        pdf_location = common.downloaddocument(
                                            file_url, 
                                            dset['versionId'], 
                                            pdf_folder, 
                                            common.cleanFileName(dataFile['filename'])
                                        )
                                        print(f"downloaded pdf")
                                    except Exception as e:
                                        print(f"could not download pdf, error:")
                                        print(e)
                                        continue

                                    # save document.json 
                                    json_output_folder = f"{json_folder}/{doc_id}"
                                    common.savejson(output_document, f"{json_output_folder}/document.json")
                    
                                    print(f"saved doc json")
                    
                                    # process pdf, store page.json files with entities 
                                    common.run_ner_on_pdf(
                                        pdf_location, 
                                        json_output_folder, 
                                        bert_model, 
                                        language
                                    )
                    
                                    print(f"ran NER, saved page json")
                    
                                    # process pdf, save html files
                                    html_output_folder = f"{html_folder}/{doc_id}"
                                    common.pdf2html(pdf_location, html_output_folder)
                    
                                    print(f"generated and saved html")
                    
                                    # save last id we indexed in the settings file 
                                    # (do this in the loop instead of after, in case we get errors/hanging that ends the script before we get to the end)
                                    common.update_config(module_name, 'last_indexed_date', dset['published_at'])
                                    
                                    print(f"updated config with latest date: {dset['published_at']}")
                                          

                                else:
                                    print ('embargoed: '+ dset['name'])
                            else:
                                print ('restricted: ' + dset['name'])
                        #else:
                             #print ('not pdf: ' + dataFile['filename'])
                                 

            else:
                print (dset['global_id'] + ' no dataset metadata found')
else:
    print ('Processing: 0')
# Out:
# Processing: 8035 datasets
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/D4Q5ZI
# Processing file: RAAPrap_7250_SIMKA_20240806.pdf
# doc_id:180948_RAAPrap_7250_SIMKA_20240806
# already downloaded, SKIPPING
# --------------------------------------------
# Processing dataset: doi:10.17026/dans-zb4-y9vj
# Processing file: archeologisch IVOV Hengelo Binnenhavenstraat 55 definitief.pdf
# restricted: Inventariserend veldonderzoek - verkennende fase Binnenhavenstraat 55 te Hengelo, gemeente Hengelo (OV) Inventariserend veldonderzoek - verkennende fase Binnenhavenstraat 55 te Hengelo, gemeente Hengelo (OV)
# Processing file: Onderzoek_5575347100.pdf
# restricted: Inventariserend veldonderzoek - verkennende fase Binnenhavenstraat 55 te Hengelo, gemeente Hengelo (OV) Inventariserend veldonderzoek - verkennende fase Binnenhavenstraat 55 te Hengelo, gemeente Hengelo (OV)
# Processing file: pva ivo-verkennend Plangebied Binnenhavenstraat 55, Hengelo.pdf
# restricted: Inventariserend veldonderzoek - verkennende fase Binnenhavenstraat 55 te Hengelo, gemeente Hengelo (OV) Inventariserend veldonderzoek - verkennende fase Binnenhavenstraat 55 te Hengelo, gemeente Hengelo (OV)
# Processing file: Veldwerk_5575347100.pdf
# restricted: Inventariserend veldonderzoek - verkennende fase Binnenhavenstraat 55 te Hengelo, gemeente Hengelo (OV) Inventariserend veldonderzoek - verkennende fase Binnenhavenstraat 55 te Hengelo, gemeente Hengelo (OV)
# --------------------------------------------
# Processing dataset: doi:10.17026/dans-2af-ecca
# Processing file: AR946 Vlissingen Bloemenbuurt.pdf
# restricted: Vlissingen Bloemenbuurt Vlissingen Bloemenbuurt. Gemeente Vlissingen. Inventariserend Veldonderzoek door middel van verkennende boringen
# Processing file: PvA Vlissingen Bloemenbuurt.pdf
# restricted: Vlissingen Bloemenbuurt Vlissingen Bloemenbuurt. Gemeente Vlissingen. Inventariserend Veldonderzoek door middel van verkennende boringen
# --------------------------------------------
# Processing dataset: doi:10.17026/dans-zyh-6krb
# Processing file: AR887 Aardenburg Jokweg 2.pdf
# restricted: Aardenburg Jokweg 2 Aardenburg Jokweg 2. Gemeente Sluis. Archeologisch Bureauonderzoek en Inventariserend Veldonderzoek door middel van verkennende boringen
# Processing file: PvA Aardenburg Jokweg 2 Aanvullende boringen.pdf
# restricted: Aardenburg Jokweg 2 Aardenburg Jokweg 2. Gemeente Sluis. Archeologisch Bureauonderzoek en Inventariserend Veldonderzoek door middel van verkennende boringen
# Processing file: PvA Aardenburg Jokweg 2.pdf
# restricted: Aardenburg Jokweg 2 Aardenburg Jokweg 2. Gemeente Sluis. Archeologisch Bureauonderzoek en Inventariserend Veldonderzoek door middel van verkennende boringen
# --------------------------------------------
# Processing dataset: doi:10.17026/dans-z5t-5623
# Processing file: AR898 Zoutelande Duinweg 12-14.pdf
# restricted: Zoutelande Duinweg 12-14 Zoutelande Duineweg 12-14. Gemeente Veere. Archeologisch Bureauonderzoek en Inventariserend Veldonderzoek door middel van verkennende boringen
# Processing file: PvA Zoutelande Duinweg 12-14.pdf
# restricted: Zoutelande Duinweg 12-14 Zoutelande Duineweg 12-14. Gemeente Veere. Archeologisch Bureauonderzoek en Inventariserend Veldonderzoek door middel van verkennende boringen
# --------------------------------------------
# Processing dataset: doi:10.17026/dans-z34-e9dw
# Processing file: AR917 Terneuzen Rembrandtlaan 2-26, Ferdinand Bolstraat 1-19 en Tooropstraat 2-8.pdf
# restricted: Terneuzen Rembrandtlaan 2-26, Ferdinand Bolstraat 1-19 en Tooropstraat 2-8 Terneuzen Rembrandtlaan 2-26, Ferdinand Bolstraat 1-19 en Tooropstraat 2-8. Gemeente Terneuzen. Archeologisch Bureauonderzoek en Inventariserend Veldonderzoek door middel van verkennende boringen
# Processing file: PvA Terneuzen Rembrandtlaan-Tooropstraat.pdf
# restricted: Terneuzen Rembrandtlaan 2-26, Ferdinand Bolstraat 1-19 en Tooropstraat 2-8 Terneuzen Rembrandtlaan 2-26, Ferdinand Bolstraat 1-19 en Tooropstraat 2-8. Gemeente Terneuzen. Archeologisch Bureauonderzoek en Inventariserend Veldonderzoek door middel van verkennende boringen
# --------------------------------------------
# Processing dataset: doi:10.17026/dans-zrb-r64p
# Processing file: AR907 Aardenburg Herendreef-Spindlerpad.pdf
# restricted: Aardenburg Herendreef-Spindlerpad Aardenburg Herendreef-Spindlerdreef. Gemeente Sluis. Archeologisch Bureauonderzoek en Inventariserend Veldonderzoek door middel van verkennende boringen
# Processing file: PvA Aardenburg Herendreef-Spindlerpad.pdf
# restricted: Aardenburg Herendreef-Spindlerpad Aardenburg Herendreef-Spindlerdreef. Gemeente Sluis. Archeologisch Bureauonderzoek en Inventariserend Veldonderzoek door middel van verkennende boringen
# --------------------------------------------
# Processing dataset: doi:10.17026/dans-252-trya
# Processing file: AR903 Groede Barendijk.pdf
# restricted: Groede Barendijk (OBGR1854) Groede Barendijk (OBG R1854). Gemeente Sluis. Archeologisch Bureauonderzoek en Inventariserend Veldonderzoek door middel van verkennende boringen
# Processing file: PvA Groede Barendijk.pdf
# restricted: Groede Barendijk (OBGR1854) Groede Barendijk (OBG R1854). Gemeente Sluis. Archeologisch Bureauonderzoek en Inventariserend Veldonderzoek door middel van verkennende boringen
# --------------------------------------------
# Processing dataset: doi:10.17026/dans-ze9-me68
# Processing file: ASK put 1 vlak 1.pdf
# restricted: Inventariserend veldonderzoek - proefsleuven Langestraat - Vestingstraat te Oldenzaal, gemeente Oldenzaal (OV) Inventariserend veldonderzoek - proefsleuven Langestraat - Vestingstraat te Oldenzaal, gemeente Oldenzaal (OV)
# Processing file: ASK put 1 vlak 2.pdf
# restricted: Inventariserend veldonderzoek - proefsleuven Langestraat - Vestingstraat te Oldenzaal, gemeente Oldenzaal (OV) Inventariserend veldonderzoek - proefsleuven Langestraat - Vestingstraat te Oldenzaal, gemeente Oldenzaal (OV)
# Processing file: ASK put 1 vlak 2 sporenconcentratie.pdf
# restricted: Inventariserend veldonderzoek - proefsleuven Langestraat - Vestingstraat te Oldenzaal, gemeente Oldenzaal (OV) Inventariserend veldonderzoek - proefsleuven Langestraat - Vestingstraat te Oldenzaal, gemeente Oldenzaal (OV)
# Processing file: ASK put 2 vlak 2.pdf
# restricted: Inventariserend veldonderzoek - proefsleuven Langestraat - Vestingstraat te Oldenzaal, gemeente Oldenzaal (OV) Inventariserend veldonderzoek - proefsleuven Langestraat - Vestingstraat te Oldenzaal, gemeente Oldenzaal (OV)
# Processing file: Dagrapport 1 18-7-23.pdf
# restricted: Inventariserend veldonderzoek - proefsleuven Langestraat - Vestingstraat te Oldenzaal, gemeente Oldenzaal (OV) Inventariserend veldonderzoek - proefsleuven Langestraat - Vestingstraat te Oldenzaal, gemeente Oldenzaal (OV)
# Processing file: Dagrapport 2 19-7-23.pdf
# restricted: Inventariserend veldonderzoek - proefsleuven Langestraat - Vestingstraat te Oldenzaal, gemeente Oldenzaal (OV) Inventariserend veldonderzoek - proefsleuven Langestraat - Vestingstraat te Oldenzaal, gemeente Oldenzaal (OV)
# Processing file: Dagrapport 3 20-7-23.pdf
# restricted: Inventariserend veldonderzoek - proefsleuven Langestraat - Vestingstraat te Oldenzaal, gemeente Oldenzaal (OV) Inventariserend veldonderzoek - proefsleuven Langestraat - Vestingstraat te Oldenzaal, gemeente Oldenzaal (OV)
# Processing file: Fotobordjes.pdf
# restricted: Inventariserend veldonderzoek - proefsleuven Langestraat - Vestingstraat te Oldenzaal, gemeente Oldenzaal (OV) Inventariserend veldonderzoek - proefsleuven Langestraat - Vestingstraat te Oldenzaal, gemeente Oldenzaal (OV)
# Processing file: OLLA232 PvE IVO-P Langestraat-Vestingstraat Oldenzaal Definitief-parDepot.pdf
# restricted: Inventariserend veldonderzoek - proefsleuven Langestraat - Vestingstraat te Oldenzaal, gemeente Oldenzaal (OV) Inventariserend veldonderzoek - proefsleuven Langestraat - Vestingstraat te Oldenzaal, gemeente Oldenzaal (OV)
# Processing file: Onderzoek_5446905100.pdf
# restricted: Inventariserend veldonderzoek - proefsleuven Langestraat - Vestingstraat te Oldenzaal, gemeente Oldenzaal (OV) Inventariserend veldonderzoek - proefsleuven Langestraat - Vestingstraat te Oldenzaal, gemeente Oldenzaal (OV)
# Processing file: Profiel 102 (TV2).pdf
# restricted: Inventariserend veldonderzoek - proefsleuven Langestraat - Vestingstraat te Oldenzaal, gemeente Oldenzaal (OV) Inventariserend veldonderzoek - proefsleuven Langestraat - Vestingstraat te Oldenzaal, gemeente Oldenzaal (OV)
# Processing file: Profiel 201 (TV4).pdf
# restricted: Inventariserend veldonderzoek - proefsleuven Langestraat - Vestingstraat te Oldenzaal, gemeente Oldenzaal (OV) Inventariserend veldonderzoek - proefsleuven Langestraat - Vestingstraat te Oldenzaal, gemeente Oldenzaal (OV)
# Processing file: Profiel 202 en coupe insteek gracht (TV5).pdf
# restricted: Inventariserend veldonderzoek - proefsleuven Langestraat - Vestingstraat te Oldenzaal, gemeente Oldenzaal (OV) Inventariserend veldonderzoek - proefsleuven Langestraat - Vestingstraat te Oldenzaal, gemeente Oldenzaal (OV)
# Processing file: PvA Langestraat-Vestingstraat.pdf
# restricted: Inventariserend veldonderzoek - proefsleuven Langestraat - Vestingstraat te Oldenzaal, gemeente Oldenzaal (OV) Inventariserend veldonderzoek - proefsleuven Langestraat - Vestingstraat te Oldenzaal, gemeente Oldenzaal (OV)
# Processing file: Rapportage IVO-P Oldenzaal Langestraat Vestingstraat def incl bijlagen_compressed.pdf
# restricted: Inventariserend veldonderzoek - proefsleuven Langestraat - Vestingstraat te Oldenzaal, gemeente Oldenzaal (OV) Inventariserend veldonderzoek - proefsleuven Langestraat - Vestingstraat te Oldenzaal, gemeente Oldenzaal (OV)
# Processing file: Selectierapport OLLA232 -EK-depot.pdf
# restricted: Inventariserend veldonderzoek - proefsleuven Langestraat - Vestingstraat te Oldenzaal, gemeente Oldenzaal (OV) Inventariserend veldonderzoek - proefsleuven Langestraat - Vestingstraat te Oldenzaal, gemeente Oldenzaal (OV)
# Processing file: TV1.pdf
# restricted: Inventariserend veldonderzoek - proefsleuven Langestraat - Vestingstraat te Oldenzaal, gemeente Oldenzaal (OV) Inventariserend veldonderzoek - proefsleuven Langestraat - Vestingstraat te Oldenzaal, gemeente Oldenzaal (OV)
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/G2KYWP
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/3ZIKLW
# Processing file: 1407_BureauVoorArcheologie_'s-Gravenhage_Scheveningseveer_17-23_v1_def.pdf
# doc_id:180864_1407_BureauVoorArcheologie_s-Gravenhage_Scheveningseveer_17-23_v1_def
# could not download pdf, error:
# HTTP Error 403: Forbidden
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/VA64WV
# Processing file: IVO-O_rapport.pdf
# doc_id:180937_IVO-O_rapport
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180937_IVO-O_rapport.pdf to html!
# generated and saved html
# updated config with latest date: 2024-08-27T14:36:47Z
# Processing file: NYHD_PvA.pdf
# doc_id:180937_NYHD_PvA
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180937_NYHD_PvA.pdf to html!
# generated and saved html
# updated config with latest date: 2024-08-27T14:36:47Z
# Processing file: RAAPrap_4418_NYHD_20200323.pdf
# doc_id:180937_RAAPrap_4418_NYHD_20200323
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180937_RAAPrap_4418_NYHD_20200323.pdf to html!
# generated and saved html
# updated config with latest date: 2024-08-27T14:36:47Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/QDSQI5
# Processing file: KNA_IVO-O rap_NYBK_20210202.pdf
# doc_id:180939_KNA_IVO-O_rap_NYBK_20210202
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180939_KNA_IVO-O_rap_NYBK_20210202.pdf to html!
# generated and saved html
# updated config with latest date: 2024-08-27T14:38:26Z
# Processing file: NYBK_Gebrekennotitie.pdf
# doc_id:180939_NYBK_Gebrekennotitie
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180939_NYBK_Gebrekennotitie.pdf to html!
# generated and saved html
# updated config with latest date: 2024-08-27T14:38:26Z
# Processing file: nybk_PvA.pdf
# doc_id:180939_nybk_PvA
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180939_nybk_PvA.pdf to html!
# generated and saved html
# updated config with latest date: 2024-08-27T14:38:26Z
# Processing file: RAAPrap_5013_NYBK_20210309.pdf
# doc_id:180939_RAAPrap_5013_NYBK_20210309
# downloaded pdf
# saved doc json
# 'NullObject' object is not subscriptable
# 'NullObject' object is not subscriptable
# 'NullObject' object is not subscriptable
# 'NullObject' object is not subscriptable
# 'NullObject' object is not subscriptable
# 'NullObject' object is not subscriptable
# 'NullObject' object is not subscriptable
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180939_RAAPrap_5013_NYBK_20210309.pdf to html!
# generated and saved html
# updated config with latest date: 2024-08-27T14:38:26Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/EN9KWA
# Processing file: 2022-05-26 Nassaulaan 1-2 kap PDFA.pdf
# doc_id:180935_2022-05-26_Nassaulaan_1-2_kap_PDFA
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180935_2022-05-26_Nassaulaan_1-2_kap_PDFA.pdf to html!
# generated and saved html
# updated config with latest date: 2024-08-27T14:42:09Z
# Processing file: 20220608 Nassaulaan 2A BHD PDFA.pdf
# doc_id:180935_20220608_Nassaulaan_2A_BHD_PDFA
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180935_20220608_Nassaulaan_2A_BHD_PDFA.pdf to html!
# generated and saved html
# updated config with latest date: 2024-08-27T14:42:09Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/NLYVS8
# Processing file: 20240118 - Bouwhistorische verkenning - Lange Poten 21 PDFA.pdf
# doc_id:180947_20240118_-_Bouwhistorische_verkenning_-_Lange_Poten_21_PDFA
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180947_20240118_-_Bouwhistorische_verkenning_-_Lange_Poten_21_PDFA.pdf to html!
# generated and saved html
# updated config with latest date: 2024-08-27T14:44:35Z
# --------------------------------------------
# Processing dataset: doi:10.17026/dans-23j-6387
# Processing file: AR911 Oostburg Bakkersstraat 62.pdf
# restricted: Oostburg Bakkersstraat 62 Oostburg Bakkersstraat 62. Gemeente Sluis. Archeologisch Bureauonderzoek en Inventariserend Veldonderzoek door middel van verkennende boringen
# Processing file: PvA Oostburg Bakkersstraat 62.pdf
# restricted: Oostburg Bakkersstraat 62 Oostburg Bakkersstraat 62. Gemeente Sluis. Archeologisch Bureauonderzoek en Inventariserend Veldonderzoek door middel van verkennende boringen
# --------------------------------------------
# Processing dataset: doi:10.17026/dans-xkn-2bb2
# Processing file: AR885 Zuidzande Provincialeweg 2.pdf
# restricted: Zuidzande Provincialeweg 2 Zuidzande Provincialeweg 2. Gemeente Sluis. Archeologisch Bureauonderzoek en Inventariserend Veldonderzoek door middel van verkennende boringen
# Processing file: PvA Zuidzande Provincialeweg 2.pdf
# restricted: Zuidzande Provincialeweg 2 Zuidzande Provincialeweg 2. Gemeente Sluis. Archeologisch Bureauonderzoek en Inventariserend Veldonderzoek door middel van verkennende boringen
# --------------------------------------------
# Processing dataset: doi:10.17026/dans-22z-7bmb
# Processing file: AR913 s-Heer Arendskerke Lange Achterweg 19.pdf
# restricted: 's-Heer Arendskerke Lange Achterweg 19 's-Heer Arendskerke Lange Achterweg 19. Gemeente Goes. Archeologisch Bureauonderzoek en Inventariserend Veldonderzoek door middel van boringen
# Processing file: PvA sHeer Arendskerke Lange Achterweg 19.pdf
# restricted: 's-Heer Arendskerke Lange Achterweg 19 's-Heer Arendskerke Lange Achterweg 19. Gemeente Goes. Archeologisch Bureauonderzoek en Inventariserend Veldonderzoek door middel van boringen
# --------------------------------------------
# Processing dataset: doi:10.17026/dans-xms-jpq8
# Processing file: AR883 Westkapelle Baaiweg 8.pdf
# restricted: Westkapelle Baaiweg 8 Westkapelle Baaiweg 8. Gemeente Veere. Archeologisch Bureauonderzoek en Inventariserend Veldonderzoek door middel van verkennende boringen
# Processing file: PvA Westkapelle Baaiweg 8.pdf
# restricted: Westkapelle Baaiweg 8 Westkapelle Baaiweg 8. Gemeente Veere. Archeologisch Bureauonderzoek en Inventariserend Veldonderzoek door middel van verkennende boringen
# --------------------------------------------
# Processing dataset: doi:10.17026/dans-zhw-ubhm
# Processing file: bo en ivov Nieuwleusen Westerveen 75 v.2 def.pdf
# restricted: Bureauonderzoek en Inventariserend veldonderzoek - verkennende fase Westerveen 75 te Nieuwleusen, gemeente Dalfsen (OV) Bureauonderzoek en Inventariserend veldonderzoek - verkennende fase Westerveen 75 te Nieuwleusen, gemeente Dalfsen (OV)
# Processing file: Onderzoek_5602205100.pdf
# restricted: Bureauonderzoek en Inventariserend veldonderzoek - verkennende fase Westerveen 75 te Nieuwleusen, gemeente Dalfsen (OV) Bureauonderzoek en Inventariserend veldonderzoek - verkennende fase Westerveen 75 te Nieuwleusen, gemeente Dalfsen (OV)
# Processing file: pva ivo-verkennend Plangebied Westerveen 75, Nieuwleusen, Dalfsen.pdf
# restricted: Bureauonderzoek en Inventariserend veldonderzoek - verkennende fase Westerveen 75 te Nieuwleusen, gemeente Dalfsen (OV) Bureauonderzoek en Inventariserend veldonderzoek - verkennende fase Westerveen 75 te Nieuwleusen, gemeente Dalfsen (OV)
# Processing file: Veldwerk_5602205100.pdf
# restricted: Bureauonderzoek en Inventariserend veldonderzoek - verkennende fase Westerveen 75 te Nieuwleusen, gemeente Dalfsen (OV) Bureauonderzoek en Inventariserend veldonderzoek - verkennende fase Westerveen 75 te Nieuwleusen, gemeente Dalfsen (OV)
# --------------------------------------------
# Processing dataset: doi:10.17026/dans-zgt-284n
# Processing file: 10. Profielen.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: 7. conceptrapport fysische antropologie Raalte 17 juni 2024.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: 9. ASK.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: Conserveringsrapport metaal Raalte.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: Dagrapport 10 23-11-2022.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: Dagrapport 11 24-11-2022.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: Dagrapport 12 25-11-2022.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: Dagrapport 13 28-11-2022.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: Dagrapport 14 29-11-2022.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: Dagrapport 15 30-11-2022.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: Dagrapport 16 1-12-2022.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: Dagrapport 1 7-11-2022.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: Dagrapport 17 2-12-2022.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: Dagrapport 18 5-12-2022.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: Dagrapport 19 6-12-2022.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: Dagrapport 20 7-12-2022.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: Dagrapport 21 8-12-2022.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: Dagrapport 22 9-12-2022.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: Dagrapport 23 12-12-2022.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: Dagrapport 24 11-4-2023.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: Dagrapport 25 13-4-2023.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: Dagrapport 2 8-11-2022.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: Dagrapport 3 9-11-2022.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: Dagrapport 4 11-11-2022.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: Dagrapport 5 14-11-2022.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: Dagrapport 6 15-11-2022.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: Dagrapport 7 16-11-2022.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: Dagrapport 8 21-11-2022.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: Dagrapport 9 22-11-2022.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: Definitieve selectielijst monsters.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: Definitieve selectielijst vondsten.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: evaluatie-selectierapport v2 met bijlagen-parDepot_OS.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: Fotobordjes.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: Hendriks p5411_signed.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: Onderzoek_5308143100.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: PvA Raalte Marktplein v2.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: PvE_OG-AB_De Plas Markt_parOS.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: RAALG voorstel voor selectieadvies 1.0.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: RAALTE_slakmateriaal_05052024GB.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: RAGR221 AB Raalte Marktplein definitief incl bijlagen v2.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: Skeletformulieren Raalte.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# Processing file: Veldwerk_5308143100.pdf
# restricted: Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte Archeologische begeleiding Grote Markt - De Plas te Raalte, gemeente Raalte (OV)
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/IXAKBG
# Processing file: 485. Alkmaar Doelenveld.pdf
# doc_id:180499_485._Alkmaar_Doelenveld
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180499_485._Alkmaar_Doelenveld.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:02:03Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/BHRBOS
# Processing file: AA220088.R01v1.0.ARG427.pdf
# doc_id:180963_AA220088.R01v1.0.ARG427
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180963_AA220088.R01v1.0.ARG427.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:04:54Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/C6ELDD
# Processing file: AA220025.R01v1.0ARG385.pdf
# doc_id:180968_AA220025.R01v1.0ARG385
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180968_AA220025.R01v1.0ARG385.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:04:57Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/5JUSEQ
# Processing file: 24300070 bubo def gemeente leeuwarden 22-8-2024 (inclusief bijlagen).pdf
# doc_id:180996_24300070_bubo_def_gemeente_leeuwarden_22-8-2024_inclusief_bijlagen
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180996_24300070_bubo_def_gemeente_leeuwarden_22-8-2024_inclusief_bijlagen.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:11:23Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/K7HTX5
# Processing file: 23300622 pve def fam danhof 17-5-2024 (inclusief bijlagen).pdf
# doc_id:180990_23300622_pve_def_fam_danhof_17-5-2024_inclusief_bijlagen
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180990_23300622_pve_def_fam_danhof_17-5-2024_inclusief_bijlagen.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:11:26Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/5EAHYT
# Processing file: 23301161 pve versie 2 reer sloop- en grondwerken verz 8-4-2024.pdf
# doc_id:180988_23301161_pve_versie_2_reer_sloop-_en_grondwerken_verz_8-4-2024
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180988_23301161_pve_versie_2_reer_sloop-_en_grondwerken_verz_8-4-2024.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:11:29Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/PGTJU4
# Processing file: 23301018 bu def mug energie 18-7-2024 (inclusief bijlagen).pdf
# doc_id:180983_23301018_bu_def_mug_energie_18-7-2024_inclusief_bijlagen
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180983_23301018_bu_def_mug_energie_18-7-2024_inclusief_bijlagen.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:11:33Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/JW3OI0
# Processing file: 23300195 bu versie 1 anna paulowna 10052023.pdf
# doc_id:180981_23300195_bu_versie_1_anna_paulowna_10052023
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180981_23300195_bu_versie_1_anna_paulowna_10052023.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:11:37Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/1BCIUB
# Processing file: 24300365 bo def rws 28-5-2024 (inclusief bijlage).pdf
# doc_id:180978_24300365_bo_def_rws_28-5-2024_inclusief_bijlage
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180978_24300365_bo_def_rws_28-5-2024_inclusief_bijlage.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:11:52Z
# Processing file: Bijlage 1a. Boorplan boring 1-6 't Strand.pdf
# doc_id:180978_Bijlage_1a._Boorplan_boring_1-6_t_Strand
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180978_Bijlage_1a._Boorplan_boring_1-6_t_Strand.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:11:52Z
# Processing file: Bijlage 1b. Boorplan boring 7-12 Hayum.pdf
# doc_id:180978_Bijlage_1b._Boorplan_boring_7-12_Hayum
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180978_Bijlage_1b._Boorplan_boring_7-12_Hayum.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:11:52Z
# Processing file: Bijlage 1c. Boorplan boring 13-18 Wildinghe.pdf
# doc_id:180978_Bijlage_1c._Boorplan_boring_13-18_Wildinghe
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180978_Bijlage_1c._Boorplan_boring_13-18_Wildinghe.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:11:52Z
# Processing file: Bijlage 1d. Boorplan boring 19-43 Middenberm A7.pdf
# doc_id:180978_Bijlage_1d._Boorplan_boring_19-43_Middenberm_A7
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180978_Bijlage_1d._Boorplan_boring_19-43_Middenberm_A7.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:11:52Z
# Processing file: Bijlage 1e. Boorplan boring 33-58 Middenberm A7.pdf
# doc_id:180978_Bijlage_1e._Boorplan_boring_33-58_Middenberm_A7
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180978_Bijlage_1e._Boorplan_boring_33-58_Middenberm_A7.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:11:52Z
# Processing file: MF223-2 PvA 4003 Booronderzoek.pdf
# doc_id:180978_MF223-2_PvA_4003_Booronderzoek
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180978_MF223-2_PvA_4003_Booronderzoek.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:11:52Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/KMMCOU
# Processing file: 24300361 bu def ncg 15-8-2024.pdf
# doc_id:180966_24300361_bu_def_ncg_15-8-2024
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180966_24300361_bu_def_ncg_15-8-2024.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:11:55Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/YLVC48
# Processing file: 23301349 PvE v1 Bork verz 21-12-23.pdf
# doc_id:180964_23301349_PvE_v1_Bork_verz_21-12-23
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180964_23301349_PvE_v1_Bork_verz_21-12-23.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:11:58Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/H03X4K
# Processing file: Rap 6375_001742 Doetinchem De Pas vooronderzoek (1).pdf
# doc_id:180973_Rap_6375_001742_Doetinchem_De_Pas_vooronderzoek_1
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180973_Rap_6375_001742_Doetinchem_De_Pas_vooronderzoek_1.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:15:11Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/NOGC5V
# Processing file: Rap 6447_002219_Spijkenisse_Hoogwerfsingel 1A en 2 vooronderzoek.pdf
# doc_id:180975_Rap_6447_002219_Spijkenisse_Hoogwerfsingel_1A_en_2_vooronderzoek
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180975_Rap_6447_002219_Spijkenisse_Hoogwerfsingel_1A_en_2_vooronderzoek.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:15:14Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/PPPW5P
# Processing file: Rap 6446_002455_DeLier_BurgVanDoornlaan 7B vooronderzoek.pdf
# doc_id:180976_Rap_6446_002455_DeLier_BurgVanDoornlaan_7B_vooronderzoek
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180976_Rap_6446_002455_DeLier_BurgVanDoornlaan_7B_vooronderzoek.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:15:17Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/R5911T
# Processing file: Rap 5836_000357_Vught_Helvoirt percelen vooronderzoek.pdf
# doc_id:180989_Rap_5836_000357_Vught_Helvoirt_percelen_vooronderzoek
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180989_Rap_5836_000357_Vught_Helvoirt_percelen_vooronderzoek.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:19:19Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/KCFCPF
# Processing file: Rap 6389_002288_Molenlanden_Groot-Ammers_Graafland 62 vooronderzoek.pdf
# doc_id:180987_Rap_6389_002288_Molenlanden_Groot-Ammers_Graafland_62_vooronderzoek
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180987_Rap_6389_002288_Molenlanden_Groot-Ammers_Graafland_62_vooronderzoek.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:19:23Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/IDEVKU
# Processing file: Rap 6452_002430_Leiden_Future Heat trace_vooronderzoek.pdf
# doc_id:180986_Rap_6452_002430_Leiden_Future_Heat_trace_vooronderzoek
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180986_Rap_6452_002430_Leiden_Future_Heat_trace_vooronderzoek.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:19:27Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/X2Z35K
# Processing file: Rap 6217_001423_Land van Cuijk_Nachtegaalstraat Mill.pdf
# doc_id:180985_Rap_6217_001423_Land_van_Cuijk_Nachtegaalstraat_Mill
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180985_Rap_6217_001423_Land_van_Cuijk_Nachtegaalstraat_Mill.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:19:30Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/ILWNFD
# Processing file: Rap 6410_002283_Bodegraven_Zuidzijde 118+118A_vooronderzoek.pdf
# doc_id:180984_Rap_6410_002283_Bodegraven_Zuidzijde_118+118A_vooronderzoek
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180984_Rap_6410_002283_Bodegraven_Zuidzijde_118+118A_vooronderzoek.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:19:33Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/T8D2PU
# Processing file: archeologisch bo Binnenhavenstraat 55 defintitief.pdf
# doc_id:180979_archeologisch_bo_Binnenhavenstraat_55_defintitief
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180979_archeologisch_bo_Binnenhavenstraat_55_defintitief.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:23:17Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/X28INO
# Processing file: Dag en weekrapport BR-207b-22 Klokkenberg Boskamers.pdf
# doc_id:181009_Dag_en_weekrapport_BR-207b-22_Klokkenberg_Boskamers
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/181009_Dag_en_weekrapport_BR-207b-22_Klokkenberg_Boskamers.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:29:57Z
# Processing file: Deselectierapport BR-207b-22.pdf
# doc_id:181009_Deselectierapport_BR-207b-22
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/181009_Deselectierapport_BR-207b-22.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:29:57Z
# Processing file: Erfgoedbesluit 2022-23 Klokkenberg Boskamers.pdf
# doc_id:181009_Erfgoedbesluit_2022-23_Klokkenberg_Boskamers
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/181009_Erfgoedbesluit_2022-23_Klokkenberg_Boskamers.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:29:57Z
# Processing file: Erfgoedrapport 368 Klokkenberg Boskamers.pdf
# doc_id:181009_Erfgoedrapport_368_Klokkenberg_Boskamers
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/181009_Erfgoedrapport_368_Klokkenberg_Boskamers.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:29:57Z
# Processing file: Evaluatierapport IVO-P Klokkenberg Boskamers.pdf
# doc_id:181009_Evaluatierapport_IVO-P_Klokkenberg_Boskamers
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/181009_Evaluatierapport_IVO-P_Klokkenberg_Boskamers.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:29:57Z
# Processing file: PvA 2022-09 Klokkenberg Boskamers.pdf
# doc_id:181009_PvA_2022-09_Klokkenberg_Boskamers
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/181009_PvA_2022-09_Klokkenberg_Boskamers.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:29:57Z
# Processing file: PvE 2022-09 Klokkenberg Boskamers v2.pdf
# doc_id:181009_PvE_2022-09_Klokkenberg_Boskamers_v2
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/181009_PvE_2022-09_Klokkenberg_Boskamers_v2.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:29:57Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/ERZEBZ
# Processing file: Dagrapport BR-690-22.pdf
# doc_id:180992_Dagrapport_BR-690-22
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180992_Dagrapport_BR-690-22.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:33:51Z
# Processing file: Deselectierapport BR-690-22.pdf
# doc_id:180992_Deselectierapport_BR-690-22
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180992_Deselectierapport_BR-690-22.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:33:51Z
# Processing file: PvA Mr. Bierensweg 43a.pdf
# doc_id:180992_PvA_Mr._Bierensweg_43a
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180992_PvA_Mr._Bierensweg_43a.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:33:51Z
# Processing file: PvE 2022-22 Mr. Bierensweg 43a.pdf
# doc_id:180992_PvE_2022-22_Mr._Bierensweg_43a
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180992_PvE_2022-22_Mr._Bierensweg_43a.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:33:51Z
# Processing file: Tek. 1.pdf
# doc_id:180992_Tek._1
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/180992_Tek._1.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:33:51Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/JSJAIL
# Processing file: AD_PvE Singelgrachtgarage_40.pdf
# doc_id:181040_AD_PvE_Singelgrachtgarage_40
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/181040_AD_PvE_Singelgrachtgarage_40.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:44:51Z
# Processing file: Codeboek.pdf
# doc_id:181040_Codeboek
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/181040_Codeboek.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:44:51Z
# Processing file: RA_AAR149FHP_10-.pdf
# doc_id:181040_RA_AAR149FHP_10-
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/181040_RA_AAR149FHP_10-.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:44:51Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/ZVPNZS
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/URE0W1
# Processing file: Laagland Archeologie rapport Stadsweg 56 te Ten Post een bureauonderzoek defintief.pdf
# doc_id:181011_Laagland_Archeologie_rapport_Stadsweg_56_te_Ten_Post_een_bureauonderzoek_defintief
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/181011_Laagland_Archeologie_rapport_Stadsweg_56_te_Ten_Post_een_bureauonderzoek_defintief.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:49:17Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/VLJSX1
# Processing file: 24040099 Rapportage BO IVO Groesbeek, Molenweg 31_DEF_compleet.pdf
# doc_id:181021_24040099_Rapportage_BO_IVO_Groesbeek_Molenweg_31_DEF_compleet
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/181021_24040099_Rapportage_BO_IVO_Groesbeek_Molenweg_31_DEF_compleet.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:54:40Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/W7RM1N
# Processing file: 21120044 Rapportage IVO-P Oirschot Beerseweg 6 - versie 2.2.pdf
# doc_id:181019_21120044_Rapportage_IVO-P_Oirschot_Beerseweg_6_-_versie_2.2
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/181019_21120044_Rapportage_IVO-P_Oirschot_Beerseweg_6_-_versie_2.2.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:54:42Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/8UDKQY
# Processing file: 24050011 Rapportage IVO-P Hooge Mierde, Koestraat 19 - versie 2.0DEF.pdf
# doc_id:181018_24050011_Rapportage_IVO-P_Hooge_Mierde_Koestraat_19_-_versie_2.0DEF
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/181018_24050011_Rapportage_IVO-P_Hooge_Mierde_Koestraat_19_-_versie_2.0DEF.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:54:45Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/YKSMNJ
# Processing file: 24020005 Rapportage BO IVO Meeuwen, Moleneind 2 definitieve versie.pdf
# doc_id:181016_24020005_Rapportage_BO_IVO_Meeuwen_Moleneind_2_definitieve_versie
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/181016_24020005_Rapportage_BO_IVO_Meeuwen_Moleneind_2_definitieve_versie.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:54:48Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/URIM7C
# Processing file: 24020130 Rapportage BO IVO Hazerswoude-Dorp definitief rapport.pdf
# doc_id:181014_24020130_Rapportage_BO_IVO_Hazerswoude-Dorp_definitief_rapport
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/181014_24020130_Rapportage_BO_IVO_Hazerswoude-Dorp_definitief_rapport.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:54:51Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/YTCVXP
# Processing file: (25448.001) Eindrapportage archeologisch vooronderzoek Johanniterweg 4 in Doorwerth.pdf
# doc_id:181028_25448.001_Eindrapportage_archeologisch_vooronderzoek_Johanniterweg_4_in_Doorwerth
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/181028_25448.001_Eindrapportage_archeologisch_vooronderzoek_Johanniterweg_4_in_Doorwerth.pdf to html!
# generated and saved html
# updated config with latest date: 2024-09-02T09:58:10Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/OPV3B8
# Processing file: (25738.001) Eindrapportage archeologisch vooronderzoek hoek Sint Jansgildestraat en Schaapsdrift in Beek (Gld.).pdf
# ...
# doc_id:280470_RAAP_PvE_2957_Gmeer11_20231205_getekend
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/280470_RAAP_PvE_2957_Gmeer11_20231205_getekend.pdf to html!
# generated and saved html
# updated config with latest date: 2025-02-24T08:56:19Z
# Processing file: RAAPrap_7029_Gmeer11_20240718.pdf
# doc_id:280470_RAAPrap_7029_Gmeer11_20240718
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/280470_RAAPrap_7029_Gmeer11_20240718.pdf to html!
# generated and saved html
# updated config with latest date: 2025-02-24T08:56:19Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/OA7M9F
# Processing file: RAAPrap_7520_EDLG_20250129.pdf
# doc_id:280721_RAAPrap_7520_EDLG_20250129
# downloaded pdf
# saved doc json
# 'NullObject' object is not subscriptable
# 'NullObject' object is not subscriptable
# 'NullObject' object is not subscriptable
# 'NullObject' object is not subscriptable
# 'NullObject' object is not subscriptable
# 'NullObject' object is not subscriptable
# 'NullObject' object is not subscriptable
# 'NullObject' object is not subscriptable
# 'NullObject' object is not subscriptable
# 'NullObject' object is not subscriptable
# 'NullObject' object is not subscriptable
# 'NullObject' object is not subscriptable
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/280721_RAAPrap_7520_EDLG_20250129.pdf to html!
# generated and saved html
# updated config with latest date: 2025-02-24T08:58:21Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/HBU1YI
# Processing file: RAAPrap_7509_WOED_20241216.pdf
# doc_id:280157_RAAPrap_7509_WOED_20241216
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/280157_RAAPrap_7509_WOED_20241216.pdf to html!
# generated and saved html
# updated config with latest date: 2025-02-24T09:00:06Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/OHOULL
# Processing file: AA230062.R01v1.0.ARG548.pdf
# doc_id:280676_AA230062.R01v1.0.ARG548
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/280676_AA230062.R01v1.0.ARG548.pdf to html!
# generated and saved html
# updated config with latest date: 2025-02-24T09:04:57Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/XBWXQV
# Processing file: 24301041 Rap DEF BO Alsema verz 13-2-2025.pdf
# doc_id:280722_24301041_Rap_DEF_BO_Alsema_verz_13-2-2025
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/280722_24301041_Rap_DEF_BO_Alsema_verz_13-2-2025.pdf to html!
# generated and saved html
# updated config with latest date: 2025-02-24T09:10:29Z
# Processing file: PvA Booronderzoek Exloo 24301041.pdf
# doc_id:280722_PvA_Booronderzoek_Exloo_24301041
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/280722_PvA_Booronderzoek_Exloo_24301041.pdf to html!
# generated and saved html
# updated config with latest date: 2025-02-24T09:10:29Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/IRANOF
# Processing file: Bureauonderzoek archeologie De Wielewaal Eindhoven definitief.pdf
# doc_id:280647_Bureauonderzoek_archeologie_De_Wielewaal_Eindhoven_definitief
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/280647_Bureauonderzoek_archeologie_De_Wielewaal_Eindhoven_definitief.pdf to html!
# generated and saved html
# updated config with latest date: 2025-02-24T09:27:23Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/GVLTOM
# Processing file: V-24.1012 BO+IVO_Oosterhout Denariusstraat_v2.0.pdf
# doc_id:280024_V-24.1012_BO+IVO_Oosterhout_Denariusstraat_v2.0
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/280024_V-24.1012_BO+IVO_Oosterhout_Denariusstraat_v2.0.pdf to html!
# generated and saved html
# updated config with latest date: 2025-02-24T09:29:14Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/55LFKT
# Processing file: Archeologisch booronderzoek verkennende fase, ketenpark Maasbracht (V-23.0905).pdf
# doc_id:279711_Archeologisch_booronderzoek_verkennende_fase_ketenpark_Maasbracht_V-23.0905
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/279711_Archeologisch_booronderzoek_verkennende_fase_ketenpark_Maasbracht_V-23.0905.pdf to html!
# generated and saved html
# updated config with latest date: 2025-02-24T09:30:10Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/T7PW9M
# Processing file: A6724-01 IVO-O Herinrichting dorpscentrum, Zoeterwoude_rapport_v1.3 (definitief).pdf
# doc_id:280717_A6724-01_IVO-O_Herinrichting_dorpscentrum_Zoeterwoude_rapport_v1.3_definitief
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/280717_A6724-01_IVO-O_Herinrichting_dorpscentrum_Zoeterwoude_rapport_v1.3_definitief.pdf to html!
# generated and saved html
# updated config with latest date: 2025-02-24T09:35:41Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/WM3IJO
# Processing file: Te behouden Monumenten St. Antonius van Padua.pdf
# restricted: Te behouden Monumenten St. Antonius van Padua, Waalwijk
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/M27MWI
# Processing file: Rapportage Mausoleum Def versie.pdf
# restricted: Waardestelling Mausoleum op de Paasberg te Ede
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/KX69QC
# Processing file: 002846.Naaldwijk.Boslaan nabij 8.rapport_dtp.pdf
# doc_id:280725_002846.Naaldwijk.Boslaan_nabij_8.rapport_dtp
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/280725_002846.Naaldwijk.Boslaan_nabij_8.rapport_dtp.pdf to html!
# generated and saved html
# updated config with latest date: 2025-02-24T10:06:09Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/EXV2PM
# Processing file: 002227.Lopik.1e Industrieweg 5.rapport_dtp.pdf
# doc_id:280726_002227.Lopik.1e_Industrieweg_5.rapport_dtp
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/280726_002227.Lopik.1e_Industrieweg_5.rapport_dtp.pdf to html!
# generated and saved html
# updated config with latest date: 2025-02-24T10:18:14Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/RUH4CV
# Processing file: 002122.Oud-Alblas.Oosteinde 46B.rapport_dtp.pdf
# doc_id:280728_002122.Oud-Alblas.Oosteinde_46B.rapport_dtp
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/280728_002122.Oud-Alblas.Oosteinde_46B.rapport_dtp.pdf to html!
# generated and saved html
# updated config with latest date: 2025-02-24T10:25:48Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/ZVEXSS
# Processing file: 879 Moerdijk Blokdijk 1-dtp.pdf
# doc_id:280729_879_Moerdijk_Blokdijk_1-dtp
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/280729_879_Moerdijk_Blokdijk_1-dtp.pdf to html!
# generated and saved html
# updated config with latest date: 2025-02-24T10:27:52Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/XJC2SZ
# Processing file: 2615 Brabantse Delta, Dijkversterking Modri_dtp.pdf
# doc_id:280730_2615_Brabantse_Delta_Dijkversterking_Modri_dtp
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/280730_2615_Brabantse_Delta_Dijkversterking_Modri_dtp.pdf to html!
# generated and saved html
# updated config with latest date: 2025-02-24T10:30:20Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/9ODIAF
# Processing file: 000669 Wijk bij Duurstede Cothen Groenewoudseweg 8_bureauonderzoek-dtp.pdf
# doc_id:280731_000669_Wijk_bij_Duurstede_Cothen_Groenewoudseweg_8_bureauonderzoek-dtp
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/280731_000669_Wijk_bij_Duurstede_Cothen_Groenewoudseweg_8_bureauonderzoek-dtp.pdf to html!
# generated and saved html
# updated config with latest date: 2025-02-24T10:35:22Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/HXUIMZ
# Processing file: 000688-Renswoude, Oude Holleweg 44_bureau- en booronderzoek_versie 1_dtp.pdf
# doc_id:280732_000688-Renswoude_Oude_Holleweg_44_bureau-_en_booronderzoek_versie_1_dtp
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/280732_000688-Renswoude_Oude_Holleweg_44_bureau-_en_booronderzoek_versie_1_dtp.pdf to html!
# generated and saved html
# updated config with latest date: 2025-02-24T10:37:55Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/LERLOL
# Processing file: bureauonderzoek 2459 watergang Groene Loper aangepast-dtp.pdf
# doc_id:280733_bureauonderzoek_2459_watergang_Groene_Loper_aangepast-dtp
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/280733_bureauonderzoek_2459_watergang_Groene_Loper_aangepast-dtp.pdf to html!
# generated and saved html
# updated config with latest date: 2025-02-24T10:40:35Z
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/CYVFXT
# Processing file: BUOR7_dagrapport_ 12102015.pdf
# doc_id:280734_BUOR7_dagrapport__12102015
# could not download pdf, error:
# HTTP Error 403: Forbidden
# Processing file: BUOR7_dagrapport_ 13102015.pdf
# doc_id:280734_BUOR7_dagrapport__13102015
# could not download pdf, error:
# HTTP Error 403: Forbidden
# Processing file: BUOR7_Gebrekennotitie.pdf
# doc_id:280734_BUOR7_Gebrekennotitie
# could not download pdf, error:
# HTTP Error 403: Forbidden
# Processing file: BUOR7_selectiebesluit_depot.pdf
# doc_id:280734_BUOR7_selectiebesluit_depot
# could not download pdf, error:
# HTTP Error 403: Forbidden
# Processing file: NO5471_BUOR7.pdf
# doc_id:280734_NO5471_BUOR7
# could not download pdf, error:
# HTTP Error 403: Forbidden
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/SMZMTV
# Processing file: DagrapportenHABR.pdf
# doc_id:280741_DagrapportenHABR
# could not download pdf, error:
# HTTP Error 403: Forbidden
# Processing file: HABR_Gebrekennotitie.pdf
# doc_id:280741_HABR_Gebrekennotitie
# could not download pdf, error:
# HTTP Error 403: Forbidden
# Processing file: HABR_PvE riool binnenstad def.pdf
# doc_id:280741_HABR_PvE_riool_binnenstad_def
# could not download pdf, error:
# HTTP Error 403: Forbidden
# Processing file: HABR_selectiebesluit_depot.pdf
# doc_id:280741_HABR_selectiebesluit_depot
# could not download pdf, error:
# HTTP Error 403: Forbidden
# Processing file: RA3007_HABRL_kaartbijlage_1.pdf
# doc_id:280741_RA3007_HABRL_kaartbijlage_1
# could not download pdf, error:
# HTTP Error 403: Forbidden
# Processing file: RA3007_HABRL.pdf
# doc_id:280741_RA3007_HABRL
# could not download pdf, error:
# HTTP Error 403: Forbidden
# Processing file: Restauratie- en conserveringsrapport 028 HABR.pdf
# doc_id:280741_Restauratie-_en_conserveringsrapport_028_HABR
# could not download pdf, error:
# HTTP Error 403: Forbidden
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/3TXDXF
# Processing file: Vondstmelding_5683652100.pdf
# doc_id:280747_Vondstmelding_5683652100
# could not download pdf, error:
# HTTP Error 403: Forbidden
# Processing file: Waarneming Waterstaatskerk Beckum.pdf
# doc_id:280747_Waarneming_Waterstaatskerk_Beckum
# could not download pdf, error:
# HTTP Error 403: Forbidden
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/KLBHLZ
# Processing file: Akkoord depot ZH niet aanleveren gedenksteen 2025.pdf
# doc_id:280790_Akkoord_depot_ZH_niet_aanleveren_gedenksteen_2025
# could not download pdf, error:
# HTTP Error 403: Forbidden
# Processing file: BRL_SIKB_Gebrekennotitie_DVSO3.pdf
# doc_id:280790_BRL_SIKB_Gebrekennotitie_DVSO3
# could not download pdf, error:
# HTTP Error 403: Forbidden
# Processing file: DVSO3_NO6190.pdf
# doc_id:280790_DVSO3_NO6190
# could not download pdf, error:
# HTTP Error 403: Forbidden
# Processing file: DVSO3_PvE.pdf
# doc_id:280790_DVSO3_PvE
# could not download pdf, error:
# HTTP Error 403: Forbidden
# Processing file: Onderzoek_4546825100.pdf
# doc_id:280790_Onderzoek_4546825100
# could not download pdf, error:
# HTTP Error 403: Forbidden
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/VANNOJ
# Processing file: Documentatie OM5376192100  EARTH Integrated Archaeology Rapporten 286.pdf
# doc_id:280796_Documentatie_OM5376192100__EARTH_Integrated_Archaeology_Rapporten_286
# could not download pdf, error:
# HTTP Error 403: Forbidden
# Processing file: Documentatie OM5376192100 Olaya p5300_signed.pdf
# doc_id:280796_Documentatie_OM5376192100_Olaya_p5300_signed
# could not download pdf, error:
# HTTP Error 403: Forbidden
# Processing file: Documentatie OM5376192100 Onderzoek_5376192100.pdf
# doc_id:280796_Documentatie_OM5376192100_Onderzoek_5376192100
# could not download pdf, error:
# HTTP Error 403: Forbidden
# Processing file: Documentatie OM5376192100 Overzicht monsters Puttershoek.pdf
# doc_id:280796_Documentatie_OM5376192100_Overzicht_monsters_Puttershoek
# could not download pdf, error:
# HTTP Error 403: Forbidden
# Processing file: Documentatie OM5376192100 PvA Puttershoek.pdf
# doc_id:280796_Documentatie_OM5376192100_PvA_Puttershoek
# could not download pdf, error:
# HTTP Error 403: Forbidden
# Processing file: Documentatie OM5376192100 PvE 2022-082 Puttershoek Versie 2.pdf
# doc_id:280796_Documentatie_OM5376192100_PvE_2022-082_Puttershoek_Versie_2
# could not download pdf, error:
# HTTP Error 403: Forbidden
# Processing file: Documentatie OM5376192100 Resultaten Analyse bodemmonsters Puttershoek P23.pdf
# doc_id:280796_Documentatie_OM5376192100_Resultaten_Analyse_bodemmonsters_Puttershoek_P23
# could not download pdf, error:
# HTTP Error 403: Forbidden
# Processing file: Documentatie OM5376192100 Veldwerk_5376192100.pdf
# doc_id:280796_Documentatie_OM5376192100_Veldwerk_5376192100
# could not download pdf, error:
# HTTP Error 403: Forbidden
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/SCJKUQ
# Processing file: Archeologisch bureauonderzoek en IVO-verkennend Meentweg 59 te Eemnes - definitief.pdf
# doc_id:280797_Archeologisch_bureauonderzoek_en_IVO-verkennend_Meentweg_59_te_Eemnes_-_definitief
# could not download pdf, error:
# HTTP Error 403: Forbidden
# Processing file: Gebrekennotitie EEME231.pdf
# doc_id:280797_Gebrekennotitie_EEME231
# could not download pdf, error:
# HTTP Error 403: Forbidden
# Processing file: Onderzoek_5380606100.pdf
# doc_id:280797_Onderzoek_5380606100
# could not download pdf, error:
# HTTP Error 403: Forbidden
# Processing file: pva ivo-verkennendv2 Meentweg 59 Eemnes.pdf
# doc_id:280797_pva_ivo-verkennendv2_Meentweg_59_Eemnes
# could not download pdf, error:
# HTTP Error 403: Forbidden
# Processing file: Veldwerk_5380606100.pdf
# doc_id:280797_Veldwerk_5380606100
# could not download pdf, error:
# HTTP Error 403: Forbidden
# --------------------------------------------
# Processing dataset: doi:10.17026/AR/CMV9SL
# Processing file: gebrekennotitie_ADRIE2.pdf
# doc_id:280804_gebrekennotitie_ADRIE2
# could not download pdf, error:
# HTTP Error 403: Forbidden
# Processing file: KNA_IVO-O rap_ADRIE2_20240116.pdf
# doc_id:280804_KNA_IVO-O_rap_ADRIE2_20240116
# could not download pdf, error:
# HTTP Error 403: Forbidden
# Processing file: RAAPpva_ADRIE2_20240112.pdf
# doc_id:280804_RAAPpva_ADRIE2_20240112
# could not download pdf, error:
# HTTP Error 403: Forbidden
# Processing file: RAAPpva_Adrie2_karterend-waarderend_20240202.pdf
# doc_id:280804_RAAPpva_Adrie2_karterend-waarderend_20240202
# could not download pdf, error:
# HTTP Error 403: Forbidden
# Processing file: RAAPrap_7055_ADRIE2_20240405.pdf
# doc_id:280804_RAAPrap_7055_ADRIE2_20240405
# could not download pdf, error:
# HTTP Error 403: Forbidden

# %%
         
# upload json and html to webserver
common.upload2webserver(json_folder, html_folder, module_name, config['webserver']['json_folder'], config['webserver']['html_folder'])

print(f"uploaded json/html to webserver")

# remotely start indexing script on webserver
common.start_index(module_name)

print(f"indexing on webserver started")

print(f"done!")
# Out:
# uploaded json/html to webserver
# indexing on webserver started
# done!
