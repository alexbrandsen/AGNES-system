# %%
# !pip install pyproj
# !pip install -U numpy==1.26.4
# !pip install transformers
# !pip install -U accelerate
# !pip install pandas
# !pip install PyPDF2
# !pip install NLTK
# !pip install editdistance
# !pip install  paramiko
# !pip install func_timeout

import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# Requirement already satisfied: pyproj in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (3.6.1)
# Requirement already satisfied: certifi in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from pyproj) (2024.7.4)
# Requirement already satisfied: numpy==1.26.4 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (1.26.4)
# Requirement already satisfied: transformers in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (4.44.1)
# Requirement already satisfied: filelock in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from transformers) (0.24.6)
# Requirement already satisfied: numpy>=1.17 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from transformers) (2024.7.24)
# Requirement already satisfied: requests in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from transformers) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from requests->transformers) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from requests->transformers) (2024.7.4)
# Requirement already satisfied: accelerate in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (0.33.0)
# Requirement already satisfied: numpy<2.0.0,>=1.17 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from accelerate) (24.1)
# Requirement already satisfied: psutil in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: pyyaml in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from accelerate) (2.4.0)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from accelerate) (0.24.6)
# Requirement already satisfied: safetensors>=0.3.1 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from accelerate) (0.4.4)
# Requirement already satisfied: filelock in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from huggingface-hub>=0.21.0->accelerate) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from huggingface-hub>=0.21.0->accelerate) (2024.6.1)
# Requirement already satisfied: requests in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.11.0)
# Requirement already satisfied: sympy in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2024.7.4)
# Requirement already satisfied: mpmath>=0.19 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: pandas in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: PyPDF2 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (3.0.1)
# Requirement already satisfied: NLTK in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (3.9.1)
# Requirement already satisfied: click in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from NLTK) (8.1.7)
# Requirement already satisfied: joblib in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from NLTK) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from NLTK) (2024.7.24)
# Requirement already satisfied: tqdm in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from NLTK) (4.66.5)
# Requirement already satisfied: editdistance in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (0.8.1)
# Requirement already satisfied: paramiko in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (3.4.1)
# Requirement already satisfied: bcrypt>=3.2 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from paramiko) (4.2.0)
# Requirement already satisfied: cryptography>=3.3 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from paramiko) (43.0.0)
# Requirement already satisfied: pynacl>=1.5 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from paramiko) (1.5.0)
# Requirement already satisfied: cffi>=1.12 in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from cryptography>=3.3->paramiko) (1.16.0)
# Requirement already satisfied: pycparser in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=3.3->paramiko) (2.21)
# Requirement already satisfied: func_timeout in /home/alex/anaconda3/envs/agnes-bert-file-import/lib/python3.11/site-packages (4.3.5)
# [nltk_data] Downloading package punkt to /home/alex/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/alex/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# import libraries
import urllib.request
import requests
import json
from pyproj import Transformer
import os
import time
import sys
from datetime import datetime
#from lxml import etree
from xml.etree import ElementTree as ET
import logging

# import common functions
sys.path.insert(1, '../')
import common

# set name of module, to fetch info from config
module_name = "dans"

# %%
# get info from config file
config = common.get_config()

# set up logging
log_location = config['data_source'][module_name]['harvest_log_location']
now = datetime.now()
date = now.strftime("%Y-%m-%d")
logfile = f"{log_location}harvest-log-{module_name}-{date}.log"
logging.basicConfig(level=logging.DEBUG, filename=logfile, filemode="a+",
                format="%(asctime)-15s %(levelname)-8s %(message)s")

# log config info        
last_indexed_date = config['data_source'][module_name]['last_indexed_date']
print(f'last_indexed_date: {last_indexed_date}')

endpoint_url = config['data_source'][module_name]['endpoint_url']
print(f'endpoint_url: {endpoint_url}')

pdf_folder = config['data_source'][module_name]['pdf_folder']
print(f'pdf_folder: {pdf_folder}')

json_folder = config['data_source'][module_name]['json_folder']
print(f'json_folder: {json_folder}')

html_folder = config['data_source'][module_name]['html_folder']
print(f'html_folder: {html_folder}')

language = config['data_source'][module_name]['language']
print(f'language: {language}')

bert_model = config['bert_models'][language]
print(f'bert_model: {bert_model}')
# Out:
# last_indexed_date: 2022-01-01T00:00:00
# endpoint_url: https://archaeology.datastations.nl/api/
# pdf_folder: /media/alex/Data/agnes_data/dans/pdf/
# json_folder: /media/alex/Data/agnes_data/dans/json/
# html_folder: /media/alex/Data/agnes_data/dans/html/
# language: dutch
# bert_model: /media/alex/Data/agnes_models/ArcheoBERTje-NER

# %%
#API settings
index_datetimestring = str(datetime.now().strftime("%Y-%m-%dT%H:%M:%S"))
providerName = 'Data_Station_Archaeology'
api_url = endpoint_url + 'search'
meta_url = endpoint_url + 'datasets/export'
content_url = endpoint_url + 'access/datafile/'
headers = {'Origin': 'http://agnessearch.nl',
           'Access-Control-Request-Method': 'GET',
           'httpAccept': 'application/json',
           'User-Agent': 'python-requests/2.18.1',
           'From': 'a.brandsen@arch.leidenuniv.nl (EXALT)'  
          }
page_length = 100  # size of the metadata chunks
datesort = "dateSort:["+str(last_indexed_date)+"Z TO "+index_datetimestring+"Z]"

# %%
params = {
            'X-Dataverse-Key': '0450fc54-e0e7-4692-b82c-e196eed69b12',  # personal API key valid till 01.05.2024
            'start': 0,                                                 # start of iteration
            'per_page': page_length,                                    # results in pages of n datasets (max. 1000)
            'type': 'dataset',
            'fq': 'publicationStatus:Published',                        # no Draft datasets
            'fq': datesort,  # everything from selected date onwards
            #'q': 'benedenberg',                                          # query (*) within archaeology.datastation.nl
            #'q': 'authorName:(schinkel AND fokkens)',                    # AND 
            #'q': 'authorName:(schinkel+OR+fokkens+OR+fontijn)',          # OR
            #'q': 'dsPublicationDate:2023',
            'q': 'dsPublicationDate:(2022 OR 2023 OR 2024 OR 2025 OR 2026 OR 2027)',                              # year of publication
            #'q': 'dsPublicationDate:(1930 OR 1950 OR 1951 OR 1952 OR 1953 OR 1954 OR 1955 OR 1956 OR 1958 OR \
            #          1959 OR 1961 OR 1962 OR 1963 OR 1964 OR 1965 OR 1966 OR 1967 OR 1968 OR 1969 \
            #          OR 1970 OR 1971 OR 1972 OR 1973 OR 1974 OR 1975 OR 1976 OR 1977 OR 1978 OR 1979 \
            #          OR 1980 OR 1981 OR 1982 OR 1983 OR 1984 OR 1985 OR 1986 OR 1987 OR 1988 OR 1989 \
            #          OR 1990 OR 1991 OR 1992 OR 1993 OR 1994 OR 1995 OR 1996 OR 1997 OR 1998 OR 1999 \
            #          OR 2000 OR 2001 OR 2002 OR 2003 OR 2004 OR 2005)',
}

# %%
# Create a requests Session
session = requests.Session()
# Set the header options, zoals 'application/json'
session.headers.update(headers)

# %%
i = 0
# Make a request and store the response
try:
    response = session.get(api_url, params=params)
    response.raise_for_status()                 # Raise error in case of failure 
except requests.exceptions.HTTPError as httpErr: 
    print ("HTTP Error:",httpErr) 
except requests.exceptions.ConnectionError as connErr: 
    print ("Error Connecting:",connErr) 
except requests.exceptions.Timeout as timeOutErr: 
    print ("Timeout Error:",timeOutErr) 
except requests.exceptions.RequestException as reqErr: 
    print ("Something Else:",reqErr)

# %%
if response.status_code == requests.codes.ok:
    
    if response:

        data = response.json()
            
        response_length = data['data']['total_count']
        print('Datasets found: '+ str(response_length))
            
        dsets = data['data']['items']

        # Fetch all the other pages of results
        page = 1
        while (page*page_length+1) <= response_length:
            params['start'] = (page*page_length)
            #print (page, params['start'])

            # GET the next page of dataset metadata
            next_response = session.get(api_url, params=params)
            if next_response.status_code == requests.codes.ok:
             if next_response:
                 next_data = next_response.json()
                 next_dsets = next_data['data']['items']
        
                 # add the data from the next page to the data we collected
                 dsets = dsets + next_dsets
            page = page + 1
            #time.sleep(1)                 # being kind to the API server

    else:
        print ('Empty result')
else:
        print ('Web connection Error')

print ('Saved: ' + str(i))
# Out:
# Datasets found: 34035
# Saved: 0

# %%
import pickle 
  
# Open a file and use dump() 
with open('dsets-TEMP.pkl', 'wb') as file: 
      
    # A new file will be created 
    pickle.dump(dsets, file)

# %%
import pickle

# Open the file in binary mode 
with open('dsets-TEMP.pkl', 'rb') as file: 
      
    # Call load method to deserialze 
    dsets = pickle.load(file)

# %%
#processing the metadata of the datasets
# date_sorted_dsets = sorted(dsets, key=lambda d: d['published_at'])
# i = 0;
# if date_sorted_dsets:
#     print ('Processing: ' + str(len(dsets)) + ' datasets')
#     for dset in date_sorted_dsets:
#         i+= 1
#         #print(json.dumps(dset, indent=4, sort_keys=False))  
#         print(dset['published_at'])  
#         if i == 300:
#             break
# Out:
# Processing: 34035 datasets
# 2022-01-02T23:00:00Z
# 2022-01-03T23:00:00Z
# 2022-01-03T23:00:00Z
# 2022-01-05T23:00:00Z
# 2022-01-06T23:00:00Z
# 2022-01-06T23:00:00Z
# 2022-01-06T23:00:00Z
# 2022-01-09T23:00:00Z
# 2022-01-09T23:00:00Z
# 2022-01-09T23:00:00Z
# 2022-01-09T23:00:00Z
# 2022-01-09T23:00:00Z
# 2022-01-09T23:00:00Z
# 2022-01-09T23:00:00Z
# 2022-01-09T23:00:00Z
# 2022-01-09T23:00:00Z
# 2022-01-09T23:00:00Z
# 2022-01-09T23:00:00Z
# 2022-01-09T23:00:00Z
# 2022-01-09T23:00:00Z
# 2022-01-10T23:00:00Z
# 2022-01-10T23:00:00Z
# 2022-01-10T23:00:00Z
# 2022-01-10T23:00:00Z
# 2022-01-10T23:00:00Z
# 2022-01-10T23:00:00Z
# 2022-01-10T23:00:00Z
# 2022-01-10T23:00:00Z
# 2022-01-10T23:00:00Z
# 2022-01-10T23:00:00Z
# 2022-01-10T23:00:00Z
# 2022-01-10T23:00:00Z
# 2022-01-10T23:00:00Z
# 2022-01-10T23:00:00Z
# 2022-01-10T23:00:00Z
# 2022-01-10T23:00:00Z
# 2022-01-11T23:00:00Z
# 2022-01-12T23:00:00Z
# 2022-01-12T23:00:00Z
# 2022-01-12T23:00:00Z
# 2022-01-12T23:00:00Z
# 2022-01-12T23:00:00Z
# 2022-01-16T23:00:00Z
# 2022-01-16T23:00:00Z
# 2022-01-16T23:00:00Z
# 2022-01-16T23:00:00Z
# 2022-01-16T23:00:00Z
# 2022-01-16T23:00:00Z
# 2022-01-16T23:00:00Z
# 2022-01-16T23:00:00Z
# 2022-01-16T23:00:00Z
# 2022-01-16T23:00:00Z
# 2022-01-16T23:00:00Z
# 2022-01-16T23:00:00Z
# 2022-01-16T23:00:00Z
# 2022-01-16T23:00:00Z
# 2022-01-16T23:00:00Z
# 2022-01-16T23:00:00Z
# 2022-01-17T23:00:00Z
# 2022-01-17T23:00:00Z
# 2022-01-17T23:00:00Z
# 2022-01-19T23:00:00Z
# 2022-01-19T23:00:00Z
# 2022-01-19T23:00:00Z
# 2022-01-19T23:00:00Z
# 2022-01-23T23:00:00Z
# 2022-01-23T23:00:00Z
# 2022-01-23T23:00:00Z
# 2022-01-23T23:00:00Z
# 2022-01-23T23:00:00Z
# 2022-01-23T23:00:00Z
# 2022-01-23T23:00:00Z
# 2022-01-23T23:00:00Z
# 2022-01-24T23:00:00Z
# 2022-01-24T23:00:00Z
# 2022-01-24T23:00:00Z
# 2022-01-24T23:00:00Z
# 2022-01-24T23:00:00Z
# 2022-01-24T23:00:00Z
# 2022-01-24T23:00:00Z
# 2022-01-24T23:00:00Z
# 2022-01-24T23:00:00Z
# 2022-01-24T23:00:00Z
# 2022-01-24T23:00:00Z
# 2022-01-24T23:00:00Z
# 2022-01-24T23:00:00Z
# 2022-01-25T23:00:00Z
# 2022-01-25T23:00:00Z
# 2022-01-25T23:00:00Z
# 2022-01-25T23:00:00Z
# 2022-01-25T23:00:00Z
# 2022-01-25T23:00:00Z
# 2022-01-25T23:00:00Z
# 2022-01-25T23:00:00Z
# 2022-01-26T23:00:00Z
# 2022-01-26T23:00:00Z
# 2022-01-26T23:00:00Z
# 2022-01-26T23:00:00Z
# 2022-01-26T23:00:00Z
# 2022-01-26T23:00:00Z
# 2022-01-26T23:00:00Z
# 2022-01-26T23:00:00Z
# 2022-01-26T23:00:00Z
# 2022-01-26T23:00:00Z
# 2022-01-26T23:00:00Z
# 2022-01-26T23:00:00Z
# 2022-01-26T23:00:00Z
# 2022-01-26T23:00:00Z
# 2022-01-26T23:00:00Z
# 2022-01-26T23:00:00Z
# 2022-01-26T23:00:00Z
# 2022-01-26T23:00:00Z
# 2022-01-26T23:00:00Z
# 2022-01-26T23:00:00Z
# 2022-01-26T23:00:00Z
# 2022-01-26T23:00:00Z
# 2022-01-26T23:00:00Z
# 2022-01-26T23:00:00Z
# 2022-01-27T23:00:00Z
# 2022-01-27T23:00:00Z
# 2022-01-27T23:00:00Z
# 2022-01-27T23:00:00Z
# 2022-01-27T23:00:00Z
# 2022-01-27T23:00:00Z
# 2022-01-27T23:00:00Z
# 2022-01-27T23:00:00Z
# 2022-01-27T23:00:00Z
# 2022-01-27T23:00:00Z
# 2022-01-27T23:00:00Z
# 2022-01-27T23:00:00Z
# 2022-01-27T23:00:00Z
# 2022-01-30T23:00:00Z
# 2022-01-30T23:00:00Z
# 2022-01-30T23:00:00Z
# 2022-01-30T23:00:00Z
# 2022-01-30T23:00:00Z
# 2022-01-30T23:00:00Z
# 2022-01-30T23:00:00Z
# 2022-01-31T23:00:00Z
# 2022-01-31T23:00:00Z
# 2022-01-31T23:00:00Z
# 2022-01-31T23:00:00Z
# 2022-01-31T23:00:00Z
# 2022-01-31T23:00:00Z
# 2022-01-31T23:00:00Z
# 2022-01-31T23:00:00Z
# 2022-01-31T23:00:00Z
# 2022-01-31T23:00:00Z
# 2022-01-31T23:00:00Z
# 2022-01-31T23:00:00Z
# 2022-01-31T23:00:00Z
# 2022-02-02T23:00:00Z
# 2022-02-02T23:00:00Z
# 2022-02-02T23:00:00Z
# 2022-02-02T23:00:00Z
# 2022-02-02T23:00:00Z
# 2022-02-02T23:00:00Z
# 2022-02-02T23:00:00Z
# 2022-02-03T23:00:00Z
# 2022-02-06T23:00:00Z
# 2022-02-06T23:00:00Z
# 2022-02-06T23:00:00Z
# 2022-02-06T23:00:00Z
# 2022-02-06T23:00:00Z
# 2022-02-06T23:00:00Z
# 2022-02-06T23:00:00Z
# 2022-02-06T23:00:00Z
# 2022-02-06T23:00:00Z
# 2022-02-06T23:00:00Z
# 2022-02-07T23:00:00Z
# 2022-02-07T23:00:00Z
# 2022-02-07T23:00:00Z
# 2022-02-07T23:00:00Z
# 2022-02-08T23:00:00Z
# 2022-02-09T23:00:00Z
# 2022-02-09T23:00:00Z
# 2022-02-09T23:00:00Z
# 2022-02-09T23:00:00Z
# 2022-02-09T23:00:00Z
# 2022-02-09T23:00:00Z
# 2022-02-09T23:00:00Z
# 2022-02-09T23:00:00Z
# 2022-02-09T23:00:00Z
# 2022-02-09T23:00:00Z
# 2022-02-09T23:00:00Z
# 2022-02-09T23:00:00Z
# 2022-02-09T23:00:00Z
# 2022-02-09T23:00:00Z
# 2022-02-09T23:00:00Z
# 2022-02-10T23:00:00Z
# 2022-02-13T23:00:00Z
# 2022-02-13T23:00:00Z
# 2022-02-13T23:00:00Z
# 2022-02-13T23:00:00Z
# 2022-02-13T23:00:00Z
# 2022-02-13T23:00:00Z
# 2022-02-13T23:00:00Z
# 2022-02-14T23:00:00Z
# 2022-02-14T23:00:00Z
# 2022-02-14T23:00:00Z
# 2022-02-14T23:00:00Z
# 2022-02-14T23:00:00Z
# 2022-02-16T23:00:00Z
# 2022-02-16T23:00:00Z
# 2022-02-16T23:00:00Z
# 2022-02-16T23:00:00Z
# 2022-02-16T23:00:00Z
# 2022-02-16T23:00:00Z
# 2022-02-16T23:00:00Z
# 2022-02-16T23:00:00Z
# 2022-02-16T23:00:00Z
# 2022-02-16T23:00:00Z
# 2022-02-16T23:00:00Z
# 2022-02-16T23:00:00Z
# 2022-02-16T23:00:00Z
# 2022-02-16T23:00:00Z
# 2022-02-16T23:00:00Z
# 2022-02-16T23:00:00Z
# 2022-02-17T23:00:00Z
# 2022-02-17T23:00:00Z
# 2022-02-17T23:00:00Z
# 2022-02-20T23:00:00Z
# 2022-02-20T23:00:00Z
# 2022-02-20T23:00:00Z
# 2022-02-20T23:00:00Z
# 2022-02-20T23:00:00Z
# 2022-02-20T23:00:00Z
# 2022-02-20T23:00:00Z
# 2022-02-20T23:00:00Z
# 2022-02-20T23:00:00Z
# 2022-02-20T23:00:00Z
# 2022-02-20T23:00:00Z
# 2022-02-21T23:00:00Z
# 2022-02-21T23:00:00Z
# 2022-02-21T23:00:00Z
# 2022-02-21T23:00:00Z
# 2022-02-21T23:00:00Z
# 2022-02-21T23:00:00Z
# 2022-02-22T23:00:00Z
# 2022-02-23T23:00:00Z
# 2022-02-27T23:00:00Z
# 2022-02-27T23:00:00Z
# 2022-02-27T23:00:00Z
# 2022-02-27T23:00:00Z
# 2022-02-27T23:00:00Z
# 2022-02-27T23:00:00Z
# 2022-02-27T23:00:00Z
# 2022-02-27T23:00:00Z
# 2022-02-27T23:00:00Z
# 2022-02-27T23:00:00Z
# 2022-02-27T23:00:00Z
# 2022-02-27T23:00:00Z
# 2022-02-27T23:00:00Z
# 2022-02-27T23:00:00Z
# 2022-02-27T23:00:00Z
# 2022-02-27T23:00:00Z
# 2022-02-27T23:00:00Z
# 2022-02-27T23:00:00Z
# 2022-02-27T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z
# 2022-02-28T23:00:00Z

# %%
#processing the metadata of the datasets
if dsets:

    # sort dsets by published date
    date_sorted_dsets = sorted(dsets, key=lambda d: d['published_at'])
    
    print ('Processing: ' + str(len(date_sorted_dsets)) + ' datasets')
    for dset in date_sorted_dsets:
        #print(json.dumps(dset, indent=4, sort_keys=False))  
        print('--------------------------------------------')
        print('Processing dataset: '+dset['global_id'])
        
        # get extended metadata
        if dset['global_id']:
            dataset_doi = dset['global_id']
            meta_params = { 'X-Dataverse-Key': '0450fc54-e0e7-4692-b82c-e196eed69b12',
                            'exporter': 'dataverse_json',                             # metadata format
                            'httpAccept': 'application/json',
                            'persistentId': dataset_doi}
            meta_response = requests.get(meta_url, params=meta_params)                # request dataset metadata
            
            if meta_response.status_code == requests.codes.ok:
                if meta_response:
                    metadata = meta_response.json()

                    #print(json.dumps(metadata, indent=4, sort_keys=False)) 
                    #exit()

                    metadataBlocks = metadata['datasetVersion']['metadataBlocks']
                    
                    files = metadata['datasetVersion']['files']
                    for file in files:
                        #print(file)
                        dataFile = file['dataFile']
                        if dataFile['contentType'] == 'application/pdf':

                            print('Processing file: '+dataFile['filename'])

                            # generate document dictionary
                            output_document = {}
                            output_document['source'] = module_name
                            output_document['file_name'] = common.cleanFileName(dataFile['filename'])
                            output_document['description'] = dset['description']
                            output_document['title'] = dset['name']
                            output_document['creators'] = dset['authors']
                            output_document['publisher'] = dset['publisher']
                            output_document['createdAt'] = dset['published_at'][:10]
                            
                            identifiers = {
                                'DOI':dset['global_id'],
                                'url':dset['url'],
                                'dans_dataset_version_id': dset['versionId']
                            }
                            if 'dansArchaeologyMetadata' in metadataBlocks:
                                for thing in metadataBlocks['dansArchaeologyMetadata']['fields']:
                                    if thing['typeName'] == 'dansArchisZaakId':
                                        identifiers['dansArchisZaakId'] = thing['value']
                            if 'dansDataVaultMetadata' in metadataBlocks:
                                for thing in metadataBlocks['dansDataVaultMetadata']['fields']:
                                    identifiers[thing['typeName']] = thing['value']
                            output_document['identifiers'] = identifiers

                            if 'citation' in metadataBlocks:
                                for thing in metadataBlocks['citation']['fields']:
                                    if thing['typeName'] == 'language':
                                        output_document['language'] = thing['value']
                            
                            # check dag/week rapport etc, so we can filter these out in ES
                            rapportList = ['dagrapport' , 'dag_rapport' , 'weekrapport' , 'week_rapport' , 'weekverslag' , 'week_verslag' , 'logboek']
                            pvaList = ['draaiboek' , 'plan_van_aanpak' , 'pva']
                            pveList = ['programma_van_eisen' , 'pve']
                            omnList = ['onderzoeksmeldingsnummer' , 'onderzoeksmeldings_nummer' , 'onderzoeks_meldings_nummer']
                            if any(word in dataFile['filename'].lower() for word in rapportList):
                                output_document['file_type'] = 'dag_week_rapport'
                            elif any(word in dataFile['filename'].lower() for word in pvaList):
                                output_document['file_type'] = 'plan_van_aanpak'
                            elif any(word in dataFile['filename'].lower() for word in pveList):
                                output_document['file_type'] = 'programma_van_eisen'
                            elif any(word in dataFile['filename'].lower() for word in omnList):
                                output_document['file_type'] = 'onderzoeksmeldingsnummer'
                            else:
                                output_document['file_type'] = 'report'
                            
                            
                            # coordinates 
                            coordX = False
                            coordY = False

                            if 'dansTemporalSpatial' in metadataBlocks:
                                for thing in metadataBlocks['dansTemporalSpatial']['fields']:
                                    if thing['typeName'] == 'dansSpatialBox':
                                        # bounding box
                                        #print(thing['value'])
                                        totalX = 0
                                        totalY = 0
                                        for box in thing['value']:
                                            totalX += (float(box['dansSpatialBoxEast']['value']) + float(box['dansSpatialBoxWest']['value'])) / 2 
                                            totalY += (float(box['dansSpatialBoxSouth']['value']) + float(box['dansSpatialBoxNorth']['value'])) / 2
                                        coordX = totalX / len(thing['value'])
                                        coordY = totalY / len(thing['value'])
                                        
                                    elif thing['typeName'] == 'dansSpatialPoint':
                                        # point
                                        #print(thing['value'])
                                        totalX = 0
                                        totalY = 0
                                        for point in thing['value']:
                                            #print(point)
                                            totalX += float(point['dansSpatialPointX']['value'])
                                            totalY += float(point['dansSpatialPointY']['value'])
                                        coordX = totalX / len(thing['value'])
                                        coordY = totalY / len(thing['value'])
                                       
                            
                            if not coordX and not coordY:
                                # no coordinates, try geocoding the location(s)
                                if 'dansTemporalSpatial' in metadataBlocks:
                                    for thing in metadataBlocks['dansTemporalSpatial']['fields']:    
                                        if thing['typeName'] == 'dansSpatialCoverageText':
                                            #print('doing GEOCODING')
                                            try:
                                                locations = thing['value']
                                                query = ''
                                                if type(locations) is list:
                                                    for location in locations:
                                                        query += location + ', ' 
                                                url = f"https://nominatim.openstreetmap.org/search?q={urllib.parse.quote(query)}&format=geojson&limit=1"
                                                #print(url)
                                                response = urllib.request.urlopen(url)
                                                data = json.loads(response.read())
                                                if len(data['features']): # if results
                                                    lat = data['features'][0]['geometry']['coordinates'][0]
                                                    lon = data['features'][0]['geometry']['coordinates'][1]
                                                    output_document['location'] = {'lat':lat,'lon':lon}
                                            except Exception as error:
                                                print('geocoding error')
                                                print(error)                                

                            if coordX and coordY:
                                output_document['coordX'] = coordX
                                output_document['coordY'] = coordY
                                #convert to lat lon
                                try:
                                    lat, lon = common.rd2wgs(coordX,coordY)
                                    output_document['location'] = {'lat':lat,'lon':lon}
                                except:
                                    print('error converting coordinates from rd to wgs for DOI '+dset['global_id'])

                            
                            # object file download (Open Access)
                            if dataFile['id'] and not file['restricted']:

                                # check for embargo
                                present = datetime.now()                                     
                                embargo = datetime.now()
                                
                                if 'embargo' in file.keys():
                                    embargo = datetime.strptime(filemeta['embargo'], "%Y-%m-%d")
                                
                                if not embargo.date() > present.date(): 

                                    # set document identifier
                                    doc_id = f"{dset['versionId']}_{common.cleanFileName(dataFile['filename'].replace('.pdf',''))}"
                                    
                                    print(f"doc_id:{doc_id}")

                                    # TEMP if already downloaded, skip
                                    output_location = f"{pdf_folder}{dset['versionId']}_{common.cleanFileName(dataFile['filename'])}"
                                    if os.path.isfile(output_location):
                                        print('already downloaded, SKIPPING')
                                        continue

                                    # sometimes get download error, so try and continue if error
                                    try:
                                        # download pdf
                                        file_url = content_url + str(dataFile['id'] ) 
                                        pdf_location = common.downloaddocument(
                                            file_url, 
                                            dset['versionId'], 
                                            pdf_folder, 
                                            common.cleanFileName(dataFile['filename'])
                                        )
                                        print(f"downloaded pdf")
                                    except Exception as e:
                                        print(f"could not download pdf, error:")
                                        print(e)
                                        continue

                                    # save document.json 
                                    json_output_folder = f"{json_folder}/{doc_id}"
                                    common.savejson(output_document, f"{json_output_folder}/document.json")
                    
                                    print(f"saved doc json")
                    
                                    # process pdf, store page.json files with entities 
                                    common.run_ner_on_pdf(
                                        pdf_location, 
                                        json_output_folder, 
                                        bert_model, 
                                        language
                                    )
                    
                                    print(f"ran NER, saved page json")
                    
                                    # process pdf, save html files
                                    html_output_folder = f"{html_folder}/{doc_id}"
                                    common.pdf2html(pdf_location, html_output_folder)
                    
                                    print(f"generated and saved html")
                    
                                    # save last id we indexed in the settings file 
                                    # (do this in the loop instead of after, in case we get errors/hanging that ends the script before we get to the end)
                                    common.update_config(module_name, 'last_indexed_date', dset['published_at'])
                                    
                                    print(f"updated config with latest date: {dset['published_at']}")
                                          

                                else:
                                    print ('embargoed: '+ dset['name'])
                            else:
                                print ('restricted: ' + dset['name'])
                        #else:
                             #print ('not pdf: ' + dataFile['filename'])
                                 

            else:
                print (dset['global_id'] + ' no dataset metadata found')
else:
    print ('Processing: 0')
# Out:
# Processing: 34035 datasets
# --------------------------------------------
# Processing dataset: doi:10.17026/dans-283-urkb
# Processing file: Rap 5665_4230718_Utrechtse Heuvelrug Maarsbergen Maarn Anderstein Valkenheide, vooronderzoek.pdf
# doc_id:85329_Rap_5665_4230718_Utrechtse_Heuvelrug_Maarsbergen_Maarn_Anderstein_Valkenheide_vooronderzoek
# already downloaded, SKIPPING
# --------------------------------------------
# Processing dataset: doi:10.17026/dans-xr2-s438
# --------------------------------------------
# Processing dataset: doi:10.17026/dans-x4y-pby9
# Processing file: Rap 5231_ 4220215_Defensie, DEM-Erfgoed, Perceel Noord 2, acht bureauonderzoeken.pdf
# doc_id:84260_Rap_5231__4220215_Defensie_DEM-Erfgoed_Perceel_Noord_2_acht_bureauonderzoeken
# already downloaded, SKIPPING
# --------------------------------------------
# Processing dataset: doi:10.17026/dans-
# --------------------------------------------
# Processing dataset: doi:10.17026/dans-xb3-mwaf
# Processing file: 2021.07 P01356 BO en IVO-O Galgendaal 26-28 Gendt D1.pdf
# doc_id:177726_2021.07_P01356_BO_en_IVO-O_Galgendaal_26-28_Gendt_D1
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/177726_2021.07_P01356_BO_en_IVO-O_Galgendaal_26-28_Gendt_D1.pdf to html!
# generated and saved html
# updated config with latest date: 2022-07-17T22:00:00Z
# --------------------------------------------
# Processing dataset: doi:10.17026/dans-zad-da4k
# Processing file: 2021.08 P01580_GRA_AR_rapportage_BO_IVO_Hof_van_Saksen_D1.pdf
# doc_id:177727_2021.08_P01580_GRA_AR_rapportage_BO_IVO_Hof_van_Saksen_D1
# downloaded pdf
# saved doc json
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/dans/pdf/177727_2021.08_P01580_GRA_AR_rapportage_BO_IVO_Hof_van_Saksen_D1.pdf to html!
# generated and saved html
# updated config with latest date: 2022-07-17T22:00:00Z
# --------------------------------------------
# Processing dataset: doi:10.17026/dans-2zg-9e42
# Processing file: 2021.14 P01812_GRA_AR_rapportage_BO_IVO_Julianastraat_Emmen_D1.pdf
# doc_id:177728_2021.14_P01812_GRA_AR_rapportage_BO_IVO_Julianastraat_Emmen_D1
# downloaded pdf
# saved doc json
# ran NER, saved page json

# %%
         
# upload json and html to webserver
common.upload2webserver(json_folder, html_folder, module_name, config['webserver']['json_folder'], config['webserver']['html_folder'])

print(f"uploaded json/html to webserver")

# remotely start indexing script on webserver
common.start_index(module_name)

print(f"indexing on webserver started")

print(f"done!")
# Out:
# Processing id:2960
# doc_id:2960_Rapport_1409_Bilzen_Kloosterstraat_EV
# saved doc json
# file /media/alex/Data/agnes_data/onroerend_erfgoed/pdf/2960_Rapport_1409_Bilzen_Kloosterstraat_EV.pdf has already been downloaded
# downloaded pdf
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# ran NER, saved page json
# Superfluous whitespace found in object header b'1' b'0'
# Superfluous whitespace found in object header b'2' b'0'
# Superfluous whitespace found in object header b'3' b'0'
# Superfluous whitespace found in object header b'31' b'0'
# Superfluous whitespace found in object header b'42' b'0'
# Superfluous whitespace found in object header b'61' b'0'
# Superfluous whitespace found in object header b'72' b'0'
# Superfluous whitespace found in object header b'100' b'0'
# Superfluous whitespace found in object header b'118' b'0'
# Superfluous whitespace found in object header b'128' b'0'
# Superfluous whitespace found in object header b'138' b'0'
# Superfluous whitespace found in object header b'141' b'0'
# Superfluous whitespace found in object header b'144' b'0'
# Superfluous whitespace found in object header b'148' b'0'
# Superfluous whitespace found in object header b'151' b'0'
# Superfluous whitespace found in object header b'154' b'0'
# Superfluous whitespace found in object header b'157' b'0'
# Superfluous whitespace found in object header b'167' b'0'
# Superfluous whitespace found in object header b'170' b'0'
# Superfluous whitespace found in object header b'173' b'0'
# Superfluous whitespace found in object header b'177' b'0'
# Superfluous whitespace found in object header b'181' b'0'
# Superfluous whitespace found in object header b'184' b'0'
# Superfluous whitespace found in object header b'194' b'0'
# Superfluous whitespace found in object header b'204' b'0'
# Superfluous whitespace found in object header b'214' b'0'
# Superfluous whitespace found in object header b'217' b'0'
# Superfluous whitespace found in object header b'227' b'0'
# Superfluous whitespace found in object header b'230' b'0'
# Superfluous whitespace found in object header b'234' b'0'
# Superfluous whitespace found in object header b'239' b'0'
# Superfluous whitespace found in object header b'249' b'0'
# Superfluous whitespace found in object header b'253' b'0'
# Superfluous whitespace found in object header b'257' b'0'
# Superfluous whitespace found in object header b'262' b'0'
# Superfluous whitespace found in object header b'268' b'0'
# Superfluous whitespace found in object header b'272' b'0'
# Superfluous whitespace found in object header b'278' b'0'
# Superfluous whitespace found in object header b'286' b'0'
# Superfluous whitespace found in object header b'290' b'0'
# Superfluous whitespace found in object header b'295' b'0'
# Superfluous whitespace found in object header b'301' b'0'
# Superfluous whitespace found in object header b'307' b'0'
# Superfluous whitespace found in object header b'312' b'0'
# Superfluous whitespace found in object header b'322' b'0'
# Superfluous whitespace found in object header b'326' b'0'
# Superfluous whitespace found in object header b'347' b'0'
# Superfluous whitespace found in object header b'351' b'0'
# Superfluous whitespace found in object header b'361' b'0'
# Superfluous whitespace found in object header b'373' b'0'
# Superfluous whitespace found in object header b'393' b'0'
# Superfluous whitespace found in object header b'403' b'0'
# Superfluous whitespace found in object header b'410' b'0'
# Superfluous whitespace found in object header b'415' b'0'
# Superfluous whitespace found in object header b'418' b'0'
# Superfluous whitespace found in object header b'424' b'0'
# Superfluous whitespace found in object header b'434' b'0'
# Superfluous whitespace found in object header b'439' b'0'
# Superfluous whitespace found in object header b'442' b'0'
# Superfluous whitespace found in object header b'452' b'0'
# Superfluous whitespace found in object header b'458' b'0'
# Superfluous whitespace found in object header b'468' b'0'
# Superfluous whitespace found in object header b'471' b'0'
# Superfluous whitespace found in object header b'474' b'0'
# Superfluous whitespace found in object header b'477' b'0'
# Superfluous whitespace found in object header b'480' b'0'
# Superfluous whitespace found in object header b'483' b'0'
# Superfluous whitespace found in object header b'486' b'0'
# Superfluous whitespace found in object header b'489' b'0'
# Superfluous whitespace found in object header b'492' b'0'
# Superfluous whitespace found in object header b'495' b'0'
# Superfluous whitespace found in object header b'30' b'0'
# Superfluous whitespace found in object header b'11' b'0'
# Superfluous whitespace found in object header b'10' b'0'
# Superfluous whitespace found in object header b'9' b'0'
# Superfluous whitespace found in object header b'20' b'0'
# Superfluous whitespace found in object header b'19' b'0'
# Superfluous whitespace found in object header b'18' b'0'
# Superfluous whitespace found in object header b'29' b'0'
# Superfluous whitespace found in object header b'12' b'0'
# Superfluous whitespace found in object header b'21' b'0'
# Superfluous whitespace found in object header b'22' b'0'
# Superfluous whitespace found in object header b'23' b'0'
# Superfluous whitespace found in object header b'24' b'0'
# Superfluous whitespace found in object header b'25' b'0'
# Superfluous whitespace found in object header b'26' b'0'
# Superfluous whitespace found in object header b'27' b'0'
# Superfluous whitespace found in object header b'28' b'0'
# Superfluous whitespace found in object header b'41' b'0'
# Superfluous whitespace found in object header b'39' b'0'
# Superfluous whitespace found in object header b'38' b'0'
# Superfluous whitespace found in object header b'37' b'0'
# Superfluous whitespace found in object header b'40' b'0'
# Superfluous whitespace found in object header b'60' b'0'
# Superfluous whitespace found in object header b'50' b'0'
# Superfluous whitespace found in object header b'49' b'0'
# Superfluous whitespace found in object header b'48' b'0'
# Superfluous whitespace found in object header b'58' b'0'
# Superfluous whitespace found in object header b'57' b'0'
# Superfluous whitespace found in object header b'56' b'0'
# Superfluous whitespace found in object header b'59' b'0'
# Converted /media/alex/Data/agnes_data/onroerend_erfgoed/pdf/2960_Rapport_1409_Bilzen_Kloosterstraat_EV.pdf to html!
# generated and saved html
# updated config with latest id: 2960
# Processing id:2961
# doc_id:2961_2023-0739_Aartselaar_Oeyvaersbosch_EV_DEF
# saved doc json
# file /media/alex/Data/agnes_data/onroerend_erfgoed/pdf/2961_2023-0739_Aartselaar_Oeyvaersbosch_EV_DEF.pdf has already been downloaded
# downloaded pdf
# Superfluous whitespace found in object header b'71' b'0'
# Superfluous whitespace found in object header b'69' b'0'
# Superfluous whitespace found in object header b'68' b'0'
# Superfluous whitespace found in object header b'67' b'0'
# Superfluous whitespace found in object header b'70' b'0'
# Superfluous whitespace found in object header b'99' b'0'
# Superfluous whitespace found in object header b'81' b'0'
# Superfluous whitespace found in object header b'80' b'0'
# Superfluous whitespace found in object header b'79' b'0'
# Superfluous whitespace found in object header b'89' b'0'
# Superfluous whitespace found in object header b'88' b'0'
# Superfluous whitespace found in object header b'87' b'0'
# Superfluous whitespace found in object header b'97' b'0'
# Superfluous whitespace found in object header b'96' b'0'
# Superfluous whitespace found in object header b'95' b'0'
# Superfluous whitespace found in object header b'98' b'0'
# Superfluous whitespace found in object header b'73' b'0'
# Superfluous whitespace found in object header b'117' b'0'
# Superfluous whitespace found in object header b'108' b'0'
# Superfluous whitespace found in object header b'107' b'0'
# Superfluous whitespace found in object header b'106' b'0'
# Superfluous whitespace found in object header b'116' b'0'
# Superfluous whitespace found in object header b'109' b'0'
# Superfluous whitespace found in object header b'110' b'0'
# Superfluous whitespace found in object header b'111' b'0'
# Superfluous whitespace found in object header b'112' b'0'
# Superfluous whitespace found in object header b'113' b'0'
# Superfluous whitespace found in object header b'114' b'0'
# Superfluous whitespace found in object header b'115' b'0'
# Superfluous whitespace found in object header b'127' b'0'
# Superfluous whitespace found in object header b'126' b'0'
# Superfluous whitespace found in object header b'119' b'0'
# Superfluous whitespace found in object header b'120' b'0'
# Superfluous whitespace found in object header b'121' b'0'
# Superfluous whitespace found in object header b'122' b'0'
# Superfluous whitespace found in object header b'123' b'0'
# Superfluous whitespace found in object header b'124' b'0'
# Superfluous whitespace found in object header b'125' b'0'
# Superfluous whitespace found in object header b'137' b'0'
# Superfluous whitespace found in object header b'136' b'0'
# Superfluous whitespace found in object header b'129' b'0'
# Superfluous whitespace found in object header b'130' b'0'
# Superfluous whitespace found in object header b'131' b'0'
# Superfluous whitespace found in object header b'132' b'0'
# Superfluous whitespace found in object header b'133' b'0'
# Superfluous whitespace found in object header b'134' b'0'
# Superfluous whitespace found in object header b'135' b'0'
# Superfluous whitespace found in object header b'140' b'0'
# Superfluous whitespace found in object header b'139' b'0'
# Superfluous whitespace found in object header b'143' b'0'
# Superfluous whitespace found in object header b'142' b'0'
# Superfluous whitespace found in object header b'147' b'0'
# Superfluous whitespace found in object header b'146' b'0'
# Superfluous whitespace found in object header b'145' b'0'
# Superfluous whitespace found in object header b'150' b'0'
# Superfluous whitespace found in object header b'149' b'0'
# Superfluous whitespace found in object header b'153' b'0'
# Superfluous whitespace found in object header b'152' b'0'
# Superfluous whitespace found in object header b'156' b'0'
# Superfluous whitespace found in object header b'155' b'0'
# Superfluous whitespace found in object header b'166' b'0'
# Superfluous whitespace found in object header b'165' b'0'
# Superfluous whitespace found in object header b'158' b'0'
# Superfluous whitespace found in object header b'159' b'0'
# Superfluous whitespace found in object header b'160' b'0'
# Superfluous whitespace found in object header b'161' b'0'
# Superfluous whitespace found in object header b'162' b'0'
# Superfluous whitespace found in object header b'163' b'0'
# Superfluous whitespace found in object header b'164' b'0'
# Superfluous whitespace found in object header b'169' b'0'
# Superfluous whitespace found in object header b'168' b'0'
# Superfluous whitespace found in object header b'172' b'0'
# Superfluous whitespace found in object header b'171' b'0'
# Superfluous whitespace found in object header b'176' b'0'
# Superfluous whitespace found in object header b'175' b'0'
# Superfluous whitespace found in object header b'174' b'0'
# Superfluous whitespace found in object header b'180' b'0'
# Superfluous whitespace found in object header b'179' b'0'
# Superfluous whitespace found in object header b'178' b'0'
# Superfluous whitespace found in object header b'183' b'0'
# Superfluous whitespace found in object header b'182' b'0'
# Superfluous whitespace found in object header b'193' b'0'
# Superfluous whitespace found in object header b'192' b'0'
# Superfluous whitespace found in object header b'185' b'0'
# Superfluous whitespace found in object header b'186' b'0'
# Superfluous whitespace found in object header b'187' b'0'
# Superfluous whitespace found in object header b'188' b'0'
# Superfluous whitespace found in object header b'189' b'0'
# Superfluous whitespace found in object header b'190' b'0'
# Superfluous whitespace found in object header b'191' b'0'
# Superfluous whitespace found in object header b'203' b'0'
# Superfluous whitespace found in object header b'202' b'0'
# Superfluous whitespace found in object header b'195' b'0'
# Superfluous whitespace found in object header b'196' b'0'
# Superfluous whitespace found in object header b'197' b'0'
# Superfluous whitespace found in object header b'198' b'0'
# Superfluous whitespace found in object header b'199' b'0'
# Superfluous whitespace found in object header b'200' b'0'
# Superfluous whitespace found in object header b'201' b'0'
# Superfluous whitespace found in object header b'213' b'0'
# Superfluous whitespace found in object header b'212' b'0'
# Superfluous whitespace found in object header b'205' b'0'
# Superfluous whitespace found in object header b'206' b'0'
# Superfluous whitespace found in object header b'207' b'0'
# Superfluous whitespace found in object header b'208' b'0'
# Superfluous whitespace found in object header b'209' b'0'
# Superfluous whitespace found in object header b'210' b'0'
# Superfluous whitespace found in object header b'211' b'0'
# Superfluous whitespace found in object header b'216' b'0'
# Superfluous whitespace found in object header b'215' b'0'
# Superfluous whitespace found in object header b'226' b'0'
# Superfluous whitespace found in object header b'225' b'0'
# Superfluous whitespace found in object header b'218' b'0'
# Superfluous whitespace found in object header b'219' b'0'
# Superfluous whitespace found in object header b'220' b'0'
# Superfluous whitespace found in object header b'221' b'0'
# Superfluous whitespace found in object header b'222' b'0'
# Superfluous whitespace found in object header b'223' b'0'
# Superfluous whitespace found in object header b'224' b'0'
# Superfluous whitespace found in object header b'229' b'0'
# Superfluous whitespace found in object header b'228' b'0'
# Superfluous whitespace found in object header b'233' b'0'
# Superfluous whitespace found in object header b'232' b'0'
# Superfluous whitespace found in object header b'231' b'0'
# Superfluous whitespace found in object header b'238' b'0'
# Superfluous whitespace found in object header b'237' b'0'
# Superfluous whitespace found in object header b'235' b'0'
# Superfluous whitespace found in object header b'236' b'0'
# Superfluous whitespace found in object header b'248' b'0'
# Superfluous whitespace found in object header b'247' b'0'
# Superfluous whitespace found in object header b'240' b'0'
# Superfluous whitespace found in object header b'241' b'0'
# Superfluous whitespace found in object header b'242' b'0'
# Superfluous whitespace found in object header b'243' b'0'
# Superfluous whitespace found in object header b'244' b'0'
# Superfluous whitespace found in object header b'245' b'0'
# Superfluous whitespace found in object header b'246' b'0'
# Superfluous whitespace found in object header b'252' b'0'
# Superfluous whitespace found in object header b'251' b'0'
# Superfluous whitespace found in object header b'250' b'0'
# Superfluous whitespace found in object header b'256' b'0'
# Superfluous whitespace found in object header b'255' b'0'
# Superfluous whitespace found in object header b'254' b'0'
# Superfluous whitespace found in object header b'261' b'0'
# Superfluous whitespace found in object header b'260' b'0'
# Superfluous whitespace found in object header b'258' b'0'
# Superfluous whitespace found in object header b'259' b'0'
# Superfluous whitespace found in object header b'267' b'0'
# Superfluous whitespace found in object header b'266' b'0'
# Superfluous whitespace found in object header b'263' b'0'
# Superfluous whitespace found in object header b'264' b'0'
# Superfluous whitespace found in object header b'265' b'0'
# Superfluous whitespace found in object header b'271' b'0'
# Superfluous whitespace found in object header b'270' b'0'
# Superfluous whitespace found in object header b'269' b'0'
# Superfluous whitespace found in object header b'277' b'0'
# Superfluous whitespace found in object header b'276' b'0'
# Superfluous whitespace found in object header b'273' b'0'
# Superfluous whitespace found in object header b'274' b'0'
# Superfluous whitespace found in object header b'275' b'0'
# Superfluous whitespace found in object header b'285' b'0'
# Superfluous whitespace found in object header b'284' b'0'
# Superfluous whitespace found in object header b'279' b'0'
# Superfluous whitespace found in object header b'280' b'0'
# Superfluous whitespace found in object header b'281' b'0'
# Superfluous whitespace found in object header b'282' b'0'
# Superfluous whitespace found in object header b'283' b'0'
# Superfluous whitespace found in object header b'289' b'0'
# Superfluous whitespace found in object header b'288' b'0'
# Superfluous whitespace found in object header b'287' b'0'
# Superfluous whitespace found in object header b'294' b'0'
# Superfluous whitespace found in object header b'293' b'0'
# Superfluous whitespace found in object header b'291' b'0'
# Superfluous whitespace found in object header b'292' b'0'
# Superfluous whitespace found in object header b'300' b'0'
# Superfluous whitespace found in object header b'299' b'0'
# Superfluous whitespace found in object header b'296' b'0'
# Superfluous whitespace found in object header b'297' b'0'
# Superfluous whitespace found in object header b'298' b'0'
# Superfluous whitespace found in object header b'306' b'0'
# Superfluous whitespace found in object header b'305' b'0'
# Superfluous whitespace found in object header b'302' b'0'
# Superfluous whitespace found in object header b'303' b'0'
# Superfluous whitespace found in object header b'304' b'0'
# Superfluous whitespace found in object header b'311' b'0'
# Superfluous whitespace found in object header b'310' b'0'
# Superfluous whitespace found in object header b'308' b'0'
# Superfluous whitespace found in object header b'309' b'0'
# Superfluous whitespace found in object header b'321' b'0'
# Superfluous whitespace found in object header b'320' b'0'
# Superfluous whitespace found in object header b'313' b'0'
# Superfluous whitespace found in object header b'314' b'0'
# Superfluous whitespace found in object header b'315' b'0'
# Superfluous whitespace found in object header b'316' b'0'
# Superfluous whitespace found in object header b'317' b'0'
# Superfluous whitespace found in object header b'318' b'0'
# Superfluous whitespace found in object header b'319' b'0'
# Superfluous whitespace found in object header b'325' b'0'
# Superfluous whitespace found in object header b'324' b'0'
# Superfluous whitespace found in object header b'323' b'0'
# Superfluous whitespace found in object header b'346' b'0'
# Superfluous whitespace found in object header b'334' b'0'
# Superfluous whitespace found in object header b'333' b'0'
# Superfluous whitespace found in object header b'332' b'0'
# Superfluous whitespace found in object header b'342' b'0'
# Superfluous whitespace found in object header b'341' b'0'
# Superfluous whitespace found in object header b'340' b'0'
# Superfluous whitespace found in object header b'345' b'0'
# Superfluous whitespace found in object header b'343' b'0'
# Superfluous whitespace found in object header b'344' b'0'
# Superfluous whitespace found in object header b'350' b'0'
# Superfluous whitespace found in object header b'349' b'0'
# Superfluous whitespace found in object header b'348' b'0'
# Superfluous whitespace found in object header b'360' b'0'
# Superfluous whitespace found in object header b'359' b'0'
# Superfluous whitespace found in object header b'352' b'0'
# Superfluous whitespace found in object header b'353' b'0'
# Superfluous whitespace found in object header b'354' b'0'
# Superfluous whitespace found in object header b'355' b'0'
# Superfluous whitespace found in object header b'356' b'0'
# Superfluous whitespace found in object header b'357' b'0'
# Superfluous whitespace found in object header b'358' b'0'
# Superfluous whitespace found in object header b'372' b'0'
# Superfluous whitespace found in object header b'371' b'0'
# Superfluous whitespace found in object header b'362' b'0'
# Superfluous whitespace found in object header b'363' b'0'
# Superfluous whitespace found in object header b'364' b'0'
# Superfluous whitespace found in object header b'365' b'0'
# Superfluous whitespace found in object header b'366' b'0'
# Superfluous whitespace found in object header b'367' b'0'
# Superfluous whitespace found in object header b'368' b'0'
# Superfluous whitespace found in object header b'369' b'0'
# Superfluous whitespace found in object header b'370' b'0'
# Superfluous whitespace found in object header b'392' b'0'
# Superfluous whitespace found in object header b'381' b'0'
# Superfluous whitespace found in object header b'380' b'0'
# Superfluous whitespace found in object header b'379' b'0'
# Superfluous whitespace found in object header b'389' b'0'
# Superfluous whitespace found in object header b'388' b'0'
# Superfluous whitespace found in object header b'387' b'0'
# Superfluous whitespace found in object header b'391' b'0'
# Superfluous whitespace found in object header b'390' b'0'
# Superfluous whitespace found in object header b'402' b'0'
# Superfluous whitespace found in object header b'401' b'0'
# Superfluous whitespace found in object header b'394' b'0'
# Superfluous whitespace found in object header b'395' b'0'
# Superfluous whitespace found in object header b'396' b'0'
# Superfluous whitespace found in object header b'397' b'0'
# Superfluous whitespace found in object header b'398' b'0'
# Superfluous whitespace found in object header b'399' b'0'
# Superfluous whitespace found in object header b'400' b'0'
# Superfluous whitespace found in object header b'409' b'0'
# Superfluous whitespace found in object header b'408' b'0'
# Superfluous whitespace found in object header b'404' b'0'
# Superfluous whitespace found in object header b'405' b'0'
# Superfluous whitespace found in object header b'406' b'0'
# Superfluous whitespace found in object header b'407' b'0'
# Superfluous whitespace found in object header b'414' b'0'
# Superfluous whitespace found in object header b'413' b'0'
# Superfluous whitespace found in object header b'411' b'0'
# Superfluous whitespace found in object header b'412' b'0'
# Superfluous whitespace found in object header b'417' b'0'
# Superfluous whitespace found in object header b'416' b'0'
# Superfluous whitespace found in object header b'423' b'0'
# Superfluous whitespace found in object header b'422' b'0'
# Superfluous whitespace found in object header b'419' b'0'
# Superfluous whitespace found in object header b'420' b'0'
# Superfluous whitespace found in object header b'421' b'0'
# Superfluous whitespace found in object header b'433' b'0'
# Superfluous whitespace found in object header b'432' b'0'
# Superfluous whitespace found in object header b'425' b'0'
# Superfluous whitespace found in object header b'426' b'0'
# Superfluous whitespace found in object header b'427' b'0'
# Superfluous whitespace found in object header b'428' b'0'
# Superfluous whitespace found in object header b'429' b'0'
# Superfluous whitespace found in object header b'430' b'0'
# Superfluous whitespace found in object header b'431' b'0'
# Superfluous whitespace found in object header b'438' b'0'
# Superfluous whitespace found in object header b'437' b'0'
# Superfluous whitespace found in object header b'435' b'0'
# Superfluous whitespace found in object header b'436' b'0'
# Superfluous whitespace found in object header b'441' b'0'
# Superfluous whitespace found in object header b'440' b'0'
# Superfluous whitespace found in object header b'451' b'0'
# Superfluous whitespace found in object header b'450' b'0'
# Superfluous whitespace found in object header b'443' b'0'
# Superfluous whitespace found in object header b'444' b'0'
# Superfluous whitespace found in object header b'445' b'0'
# Superfluous whitespace found in object header b'446' b'0'
# Superfluous whitespace found in object header b'447' b'0'
# Superfluous whitespace found in object header b'448' b'0'
# Superfluous whitespace found in object header b'449' b'0'
# Superfluous whitespace found in object header b'457' b'0'
# Superfluous whitespace found in object header b'456' b'0'
# Superfluous whitespace found in object header b'453' b'0'
# Superfluous whitespace found in object header b'454' b'0'
# Superfluous whitespace found in object header b'455' b'0'
# Superfluous whitespace found in object header b'467' b'0'
# Superfluous whitespace found in object header b'466' b'0'
# Superfluous whitespace found in object header b'459' b'0'
# Superfluous whitespace found in object header b'460' b'0'
# Superfluous whitespace found in object header b'461' b'0'
# Superfluous whitespace found in object header b'462' b'0'
# Superfluous whitespace found in object header b'463' b'0'
# Superfluous whitespace found in object header b'464' b'0'
# Superfluous whitespace found in object header b'465' b'0'
# Superfluous whitespace found in object header b'470' b'0'
# Superfluous whitespace found in object header b'469' b'0'
# Superfluous whitespace found in object header b'473' b'0'
# Superfluous whitespace found in object header b'472' b'0'
# Superfluous whitespace found in object header b'476' b'0'
# Superfluous whitespace found in object header b'475' b'0'
# Superfluous whitespace found in object header b'479' b'0'
# Superfluous whitespace found in object header b'478' b'0'
# Superfluous whitespace found in object header b'482' b'0'
# Superfluous whitespace found in object header b'481' b'0'
# Superfluous whitespace found in object header b'485' b'0'
# Superfluous whitespace found in object header b'484' b'0'
# Superfluous whitespace found in object header b'488' b'0'
# Superfluous whitespace found in object header b'487' b'0'
# Superfluous whitespace found in object header b'491' b'0'
# Superfluous whitespace found in object header b'490' b'0'
# Superfluous whitespace found in object header b'494' b'0'
# Superfluous whitespace found in object header b'493' b'0'
# Superfluous whitespace found in object header b'497' b'0'
# Superfluous whitespace found in object header b'496' b'0'
# ran NER, saved page json
# Superfluous whitespace found in object header b'2' b'0'
# Superfluous whitespace found in object header b'3' b'0'
# Superfluous whitespace found in object header b'29' b'0'
# Superfluous whitespace found in object header b'41' b'0'
# Superfluous whitespace found in object header b'44' b'0'
# Superfluous whitespace found in object header b'47' b'0'
# Superfluous whitespace found in object header b'58' b'0'
# Superfluous whitespace found in object header b'71' b'0'
# Superfluous whitespace found in object header b'76' b'0'
# Superfluous whitespace found in object header b'81' b'0'
# Superfluous whitespace found in object header b'92' b'0'
# Superfluous whitespace found in object header b'95' b'0'
# Superfluous whitespace found in object header b'98' b'0'
# Superfluous whitespace found in object header b'102' b'0'
# Superfluous whitespace found in object header b'105' b'0'
# Superfluous whitespace found in object header b'108' b'0'
# Superfluous whitespace found in object header b'112' b'0'
# Superfluous whitespace found in object header b'116' b'0'
# Superfluous whitespace found in object header b'120' b'0'
# Superfluous whitespace found in object header b'124' b'0'
# Superfluous whitespace found in object header b'127' b'0'
# Superfluous whitespace found in object header b'131' b'0'
# Superfluous whitespace found in object header b'150' b'0'
# Superfluous whitespace found in object header b'153' b'0'
# Superfluous whitespace found in object header b'158' b'0'
# Superfluous whitespace found in object header b'164' b'0'
# Superfluous whitespace found in object header b'169' b'0'
# Superfluous whitespace found in object header b'173' b'0'
# Superfluous whitespace found in object header b'176' b'0'
# Superfluous whitespace found in object header b'181' b'0'
# Superfluous whitespace found in object header b'185' b'0'
# Superfluous whitespace found in object header b'188' b'0'
# Superfluous whitespace found in object header b'191' b'0'
# Superfluous whitespace found in object header b'194' b'0'
# Superfluous whitespace found in object header b'197' b'0'
# Superfluous whitespace found in object header b'200' b'0'
# Superfluous whitespace found in object header b'203' b'0'
# Superfluous whitespace found in object header b'206' b'0'
# Superfluous whitespace found in object header b'211' b'0'
# Superfluous whitespace found in object header b'216' b'0'
# Superfluous whitespace found in object header b'219' b'0'
# Superfluous whitespace found in object header b'224' b'0'
# Superfluous whitespace found in object header b'229' b'0'
# Superfluous whitespace found in object header b'244' b'0'
# Superfluous whitespace found in object header b'259' b'0'
# Superfluous whitespace found in object header b'262' b'0'
# Superfluous whitespace found in object header b'267' b'0'
# Superfluous whitespace found in object header b'272' b'0'
# Superfluous whitespace found in object header b'277' b'0'
# Superfluous whitespace found in object header b'282' b'0'
# Superfluous whitespace found in object header b'285' b'0'
# Superfluous whitespace found in object header b'312' b'0'
# Superfluous whitespace found in object header b'315' b'0'
# Superfluous whitespace found in object header b'318' b'0'
# Superfluous whitespace found in object header b'322' b'0'
# Superfluous whitespace found in object header b'327' b'0'
# Superfluous whitespace found in object header b'403' b'0'
# Superfluous whitespace found in object header b'406' b'0'
# Superfluous whitespace found in object header b'410' b'0'
# Superfluous whitespace found in object header b'415' b'0'
# Superfluous whitespace found in object header b'478' b'0'
# Superfluous whitespace found in object header b'495' b'0'
# Superfluous whitespace found in object header b'498' b'0'
# Superfluous whitespace found in object header b'537' b'0'
# Superfluous whitespace found in object header b'552' b'0'
# Superfluous whitespace found in object header b'556' b'0'
# Superfluous whitespace found in object header b'583' b'0'
# Superfluous whitespace found in object header b'598' b'0'
# Superfluous whitespace found in object header b'602' b'0'
# Superfluous whitespace found in object header b'607' b'0'
# Superfluous whitespace found in object header b'610' b'0'
# Superfluous whitespace found in object header b'613' b'0'
# Superfluous whitespace found in object header b'616' b'0'
# Superfluous whitespace found in object header b'625' b'0'
# Superfluous whitespace found in object header b'633' b'0'
# Superfluous whitespace found in object header b'638' b'0'
# Superfluous whitespace found in object header b'643' b'0'
# Superfluous whitespace found in object header b'648' b'0'
# Superfluous whitespace found in object header b'652' b'0'
# Superfluous whitespace found in object header b'656' b'0'
# Superfluous whitespace found in object header b'661' b'0'
# Superfluous whitespace found in object header b'664' b'0'
# Superfluous whitespace found in object header b'669' b'0'
# Superfluous whitespace found in object header b'674' b'0'
# Superfluous whitespace found in object header b'687' b'0'
# Superfluous whitespace found in object header b'691' b'0'
# Superfluous whitespace found in object header b'696' b'0'
# Superfluous whitespace found in object header b'699' b'0'
# Superfluous whitespace found in object header b'702' b'0'
# Superfluous whitespace found in object header b'707' b'0'
# Superfluous whitespace found in object header b'727' b'0'
# Superfluous whitespace found in object header b'732' b'0'
# Superfluous whitespace found in object header b'735' b'0'
# Superfluous whitespace found in object header b'739' b'0'
# Superfluous whitespace found in object header b'744' b'0'
# Superfluous whitespace found in object header b'747' b'0'
# Superfluous whitespace found in object header b'751' b'0'
# Superfluous whitespace found in object header b'757' b'0'
# Superfluous whitespace found in object header b'769' b'0'
# Superfluous whitespace found in object header b'774' b'0'
# Superfluous whitespace found in object header b'777' b'0'
# Superfluous whitespace found in object header b'780' b'0'
# Superfluous whitespace found in object header b'783' b'0'
# Superfluous whitespace found in object header b'786' b'0'
# Superfluous whitespace found in object header b'789' b'0'
# Superfluous whitespace found in object header b'792' b'0'
# Superfluous whitespace found in object header b'795' b'0'
# Superfluous whitespace found in object header b'798' b'0'
# Superfluous whitespace found in object header b'801' b'0'
# Superfluous whitespace found in object header b'804' b'0'
# Superfluous whitespace found in object header b'807' b'0'
# Superfluous whitespace found in object header b'810' b'0'
# Superfluous whitespace found in object header b'813' b'0'
# Superfluous whitespace found in object header b'816' b'0'
# Superfluous whitespace found in object header b'819' b'0'
# Superfluous whitespace found in object header b'822' b'0'
# Superfluous whitespace found in object header b'843' b'0'
# Superfluous whitespace found in object header b'846' b'0'
# Superfluous whitespace found in object header b'849' b'0'
# Superfluous whitespace found in object header b'852' b'0'
# Superfluous whitespace found in object header b'858' b'0'
# Superfluous whitespace found in object header b'864' b'0'
# Superfluous whitespace found in object header b'870' b'0'
# Superfluous whitespace found in object header b'876' b'0'
# Superfluous whitespace found in object header b'882' b'0'
# Superfluous whitespace found in object header b'889' b'0'
# Superfluous whitespace found in object header b'895' b'0'
# Superfluous whitespace found in object header b'901' b'0'
# Superfluous whitespace found in object header b'907' b'0'
# Superfluous whitespace found in object header b'913' b'0'
# Superfluous whitespace found in object header b'918' b'0'
# Superfluous whitespace found in object header b'923' b'0'
# Superfluous whitespace found in object header b'929' b'0'
# Superfluous whitespace found in object header b'935' b'0'
# Converted /media/alex/Data/agnes_data/onroerend_erfgoed/pdf/2961_2023-0739_Aartselaar_Oeyvaersbosch_EV_DEF.pdf to html!
# generated and saved html
# updated config with latest id: 2961
# Processing id:2962
# doc_id:2962_ORTEC2201008_-_Eindverslag_-_Geetbets_-_Zoutleeuw_OPGR
# saved doc json
# file /media/alex/Data/agnes_data/onroerend_erfgoed/pdf/2962_ORTEC2201008_-_Eindverslag_-_Geetbets_-_Zoutleeuw_OPGR.pdf has already been downloaded
# downloaded pdf
# Superfluous whitespace found in object header b'941' b'0'
# Superfluous whitespace found in object header b'947' b'0'
# Superfluous whitespace found in object header b'953' b'0'
# Superfluous whitespace found in object header b'959' b'0'
# Superfluous whitespace found in object header b'965' b'0'
# Superfluous whitespace found in object header b'968' b'0'
# Superfluous whitespace found in object header b'974' b'0'
# Superfluous whitespace found in object header b'980' b'0'
# Superfluous whitespace found in object header b'986' b'0'
# Superfluous whitespace found in object header b'992' b'0'
# Superfluous whitespace found in object header b'998' b'0'
# Superfluous whitespace found in object header b'1004' b'0'
# Superfluous whitespace found in object header b'1010' b'0'
# Superfluous whitespace found in object header b'1016' b'0'
# Superfluous whitespace found in object header b'1019' b'0'
# Superfluous whitespace found in object header b'1022' b'0'
# Superfluous whitespace found in object header b'1025' b'0'
# Superfluous whitespace found in object header b'1028' b'0'
# Superfluous whitespace found in object header b'28' b'0'
# Superfluous whitespace found in object header b'13' b'0'
# Superfluous whitespace found in object header b'12' b'0'
# Superfluous whitespace found in object header b'11' b'0'
# Superfluous whitespace found in object header b'21' b'0'
# Superfluous whitespace found in object header b'20' b'0'
# Superfluous whitespace found in object header b'19' b'0'
# Superfluous whitespace found in object header b'27' b'0'
# Superfluous whitespace found in object header b'4' b'0'
# Superfluous whitespace found in object header b'5' b'0'
# Superfluous whitespace found in object header b'22' b'0'
# Superfluous whitespace found in object header b'23' b'0'
# Superfluous whitespace found in object header b'24' b'0'
# Superfluous whitespace found in object header b'25' b'0'
# Superfluous whitespace found in object header b'26' b'0'
# Superfluous whitespace found in object header b'40' b'0'
# Superfluous whitespace found in object header b'38' b'0'
# Superfluous whitespace found in object header b'37' b'0'
# Superfluous whitespace found in object header b'36' b'0'
# Superfluous whitespace found in object header b'39' b'0'
# Superfluous whitespace found in object header b'30' b'0'
# Superfluous whitespace found in object header b'43' b'0'
# Superfluous whitespace found in object header b'42' b'0'
# Superfluous whitespace found in object header b'46' b'0'
# Superfluous whitespace found in object header b'45' b'0'
# Superfluous whitespace found in object header b'57' b'0'
# Superfluous whitespace found in object header b'55' b'0'
# Superfluous whitespace found in object header b'54' b'0'
# Superfluous whitespace found in object header b'53' b'0'
# Superfluous whitespace found in object header b'56' b'0'
# Superfluous whitespace found in object header b'70' b'0'
# Superfluous whitespace found in object header b'66' b'0'
# Superfluous whitespace found in object header b'65' b'0'
# Superfluous whitespace found in object header b'64' b'0'
# Superfluous whitespace found in object header b'69' b'0'
# Superfluous whitespace found in object header b'67' b'0'
# Superfluous whitespace found in object header b'68' b'0'
# Superfluous whitespace found in object header b'75' b'0'
# Superfluous whitespace found in object header b'74' b'0'
# Superfluous whitespace found in object header b'72' b'0'
# Superfluous whitespace found in object header b'73' b'0'
# Superfluous whitespace found in object header b'80' b'0'
# Superfluous whitespace found in object header b'79' b'0'
# Superfluous whitespace found in object header b'77' b'0'
# Superfluous whitespace found in object header b'78' b'0'
# Superfluous whitespace found in object header b'91' b'0'
# Superfluous whitespace found in object header b'89' b'0'
# Superfluous whitespace found in object header b'88' b'0'
# Superfluous whitespace found in object header b'87' b'0'
# Superfluous whitespace found in object header b'90' b'0'
# Superfluous whitespace found in object header b'94' b'0'
# Superfluous whitespace found in object header b'93' b'0'
# Superfluous whitespace found in object header b'97' b'0'
# Superfluous whitespace found in object header b'96' b'0'
# Superfluous whitespace found in object header b'101' b'0'
# Superfluous whitespace found in object header b'100' b'0'
# Superfluous whitespace found in object header b'99' b'0'
# Superfluous whitespace found in object header b'104' b'0'
# Superfluous whitespace found in object header b'103' b'0'
# Superfluous whitespace found in object header b'107' b'0'
# Superfluous whitespace found in object header b'106' b'0'
# Superfluous whitespace found in object header b'111' b'0'
# Superfluous whitespace found in object header b'110' b'0'
# Superfluous whitespace found in object header b'109' b'0'
# Superfluous whitespace found in object header b'115' b'0'
# Superfluous whitespace found in object header b'114' b'0'
# Superfluous whitespace found in object header b'113' b'0'
# Superfluous whitespace found in object header b'119' b'0'
# Superfluous whitespace found in object header b'118' b'0'
# Superfluous whitespace found in object header b'117' b'0'
# Superfluous whitespace found in object header b'123' b'0'
# Superfluous whitespace found in object header b'122' b'0'
# Superfluous whitespace found in object header b'121' b'0'
# Superfluous whitespace found in object header b'126' b'0'
# Superfluous whitespace found in object header b'125' b'0'
# Superfluous whitespace found in object header b'130' b'0'
# Superfluous whitespace found in object header b'129' b'0'
# Superfluous whitespace found in object header b'128' b'0'
# Superfluous whitespace found in object header b'149' b'0'
# Superfluous whitespace found in object header b'139' b'0'
# Superfluous whitespace found in object header b'138' b'0'
# Superfluous whitespace found in object header b'137' b'0'
# Superfluous whitespace found in object header b'147' b'0'
# Superfluous whitespace found in object header b'146' b'0'
# Superfluous whitespace found in object header b'145' b'0'
# Superfluous whitespace found in object header b'148' b'0'
# Superfluous whitespace found in object header b'152' b'0'
# Superfluous whitespace found in object header b'151' b'0'
# Superfluous whitespace found in object header b'157' b'0'
# Superfluous whitespace found in object header b'156' b'0'
# Superfluous whitespace found in object header b'154' b'0'
# Superfluous whitespace found in object header b'155' b'0'
# Superfluous whitespace found in object header b'163' b'0'
# Superfluous whitespace found in object header b'162' b'0'
# Superfluous whitespace found in object header b'159' b'0'
# Superfluous whitespace found in object header b'160' b'0'
# Superfluous whitespace found in object header b'161' b'0'
# Superfluous whitespace found in object header b'168' b'0'
# Superfluous whitespace found in object header b'167' b'0'
# Superfluous whitespace found in object header b'165' b'0'
# Superfluous whitespace found in object header b'166' b'0'
# Superfluous whitespace found in object header b'172' b'0'
# Superfluous whitespace found in object header b'171' b'0'
# Superfluous whitespace found in object header b'170' b'0'
# Superfluous whitespace found in object header b'175' b'0'
# Superfluous whitespace found in object header b'174' b'0'
# Superfluous whitespace found in object header b'180' b'0'
# Superfluous whitespace found in object header b'179' b'0'
# Superfluous whitespace found in object header b'177' b'0'
# Superfluous whitespace found in object header b'178' b'0'
# Superfluous whitespace found in object header b'184' b'0'
# Superfluous whitespace found in object header b'183' b'0'
# Superfluous whitespace found in object header b'182' b'0'
# Superfluous whitespace found in object header b'187' b'0'
# Superfluous whitespace found in object header b'186' b'0'
# Superfluous whitespace found in object header b'190' b'0'
# Superfluous whitespace found in object header b'189' b'0'
# Superfluous whitespace found in object header b'193' b'0'
# Superfluous whitespace found in object header b'192' b'0'
# Superfluous whitespace found in object header b'196' b'0'
# Superfluous whitespace found in object header b'195' b'0'
# Superfluous whitespace found in object header b'199' b'0'
# Superfluous whitespace found in object header b'198' b'0'
# Superfluous whitespace found in object header b'202' b'0'
# Superfluous whitespace found in object header b'201' b'0'
# Superfluous whitespace found in object header b'205' b'0'
# Superfluous whitespace found in object header b'204' b'0'
# Superfluous whitespace found in object header b'210' b'0'
# Superfluous whitespace found in object header b'209' b'0'
# Superfluous whitespace found in object header b'207' b'0'
# Superfluous whitespace found in object header b'208' b'0'
# Superfluous whitespace found in object header b'215' b'0'
# Superfluous whitespace found in object header b'214' b'0'
# Superfluous whitespace found in object header b'212' b'0'
# Superfluous whitespace found in object header b'213' b'0'
# Superfluous whitespace found in object header b'218' b'0'
# Superfluous whitespace found in object header b'217' b'0'
# Superfluous whitespace found in object header b'223' b'0'
# Superfluous whitespace found in object header b'222' b'0'
# Superfluous whitespace found in object header b'220' b'0'
# Superfluous whitespace found in object header b'221' b'0'
# Superfluous whitespace found in object header b'228' b'0'
# Superfluous whitespace found in object header b'227' b'0'
# Superfluous whitespace found in object header b'225' b'0'
# Superfluous whitespace found in object header b'226' b'0'
# Superfluous whitespace found in object header b'243' b'0'
# Superfluous whitespace found in object header b'242' b'0'
# Superfluous whitespace found in object header b'230' b'0'
# Superfluous whitespace found in object header b'231' b'0'
# Superfluous whitespace found in object header b'232' b'0'
# Superfluous whitespace found in object header b'233' b'0'
# Superfluous whitespace found in object header b'234' b'0'
# Superfluous whitespace found in object header b'235' b'0'
# Superfluous whitespace found in object header b'236' b'0'
# Superfluous whitespace found in object header b'237' b'0'
# Superfluous whitespace found in object header b'238' b'0'
# Superfluous whitespace found in object header b'239' b'0'
# Superfluous whitespace found in object header b'240' b'0'
# Superfluous whitespace found in object header b'241' b'0'
# Superfluous whitespace found in object header b'258' b'0'
# Superfluous whitespace found in object header b'257' b'0'
# Superfluous whitespace found in object header b'245' b'0'
# Superfluous whitespace found in object header b'246' b'0'
# Superfluous whitespace found in object header b'247' b'0'
# Superfluous whitespace found in object header b'248' b'0'
# Superfluous whitespace found in object header b'249' b'0'
# Superfluous whitespace found in object header b'250' b'0'
# Superfluous whitespace found in object header b'251' b'0'
# Superfluous whitespace found in object header b'252' b'0'
# Superfluous whitespace found in object header b'253' b'0'
# Superfluous whitespace found in object header b'254' b'0'
# Superfluous whitespace found in object header b'255' b'0'
# Superfluous whitespace found in object header b'256' b'0'
# Superfluous whitespace found in object header b'261' b'0'
# Superfluous whitespace found in object header b'260' b'0'
# Superfluous whitespace found in object header b'266' b'0'
# Superfluous whitespace found in object header b'265' b'0'
# Superfluous whitespace found in object header b'263' b'0'
# Superfluous whitespace found in object header b'264' b'0'
# Superfluous whitespace found in object header b'271' b'0'
# Superfluous whitespace found in object header b'270' b'0'
# Superfluous whitespace found in object header b'268' b'0'
# Superfluous whitespace found in object header b'269' b'0'
# Superfluous whitespace found in object header b'276' b'0'
# Superfluous whitespace found in object header b'275' b'0'
# Superfluous whitespace found in object header b'273' b'0'
# Superfluous whitespace found in object header b'274' b'0'
# Superfluous whitespace found in object header b'281' b'0'
# Superfluous whitespace found in object header b'280' b'0'
# Superfluous whitespace found in object header b'278' b'0'
# Superfluous whitespace found in object header b'279' b'0'
# Superfluous whitespace found in object header b'284' b'0'
# Superfluous whitespace found in object header b'283' b'0'
# Superfluous whitespace found in object header b'311' b'0'
# Superfluous whitespace found in object header b'310' b'0'
# Superfluous whitespace found in object header b'286' b'0'
# Superfluous whitespace found in object header b'287' b'0'
# Superfluous whitespace found in object header b'288' b'0'
# Superfluous whitespace found in object header b'289' b'0'
# Superfluous whitespace found in object header b'290' b'0'
# Superfluous whitespace found in object header b'291' b'0'
# Superfluous whitespace found in object header b'292' b'0'
# Superfluous whitespace found in object header b'293' b'0'
# Superfluous whitespace found in object header b'294' b'0'
# Superfluous whitespace found in object header b'295' b'0'
# Superfluous whitespace found in object header b'296' b'0'
# Superfluous whitespace found in object header b'297' b'0'
# Superfluous whitespace found in object header b'298' b'0'
# Superfluous whitespace found in object header b'299' b'0'
# Superfluous whitespace found in object header b'300' b'0'
# Superfluous whitespace found in object header b'301' b'0'
# Superfluous whitespace found in object header b'302' b'0'
# Superfluous whitespace found in object header b'303' b'0'
# Superfluous whitespace found in object header b'304' b'0'
# Superfluous whitespace found in object header b'305' b'0'
# Superfluous whitespace found in object header b'306' b'0'
# Superfluous whitespace found in object header b'307' b'0'
# Superfluous whitespace found in object header b'308' b'0'
# Superfluous whitespace found in object header b'309' b'0'
# Superfluous whitespace found in object header b'314' b'0'
# Superfluous whitespace found in object header b'313' b'0'
# Superfluous whitespace found in object header b'317' b'0'
# Superfluous whitespace found in object header b'316' b'0'
# Superfluous whitespace found in object header b'321' b'0'
# Superfluous whitespace found in object header b'320' b'0'
# Superfluous whitespace found in object header b'319' b'0'
# Superfluous whitespace found in object header b'326' b'0'
# Superfluous whitespace found in object header b'325' b'0'
# Superfluous whitespace found in object header b'323' b'0'
# ...
# Superfluous whitespace found in object header b'2130' b'0'
# Superfluous whitespace found in object header b'2131' b'0'
# Superfluous whitespace found in object header b'2132' b'0'
# Superfluous whitespace found in object header b'2133' b'0'
# Superfluous whitespace found in object header b'2134' b'0'
# Superfluous whitespace found in object header b'2135' b'0'
# Superfluous whitespace found in object header b'2136' b'0'
# Superfluous whitespace found in object header b'2137' b'0'
# Superfluous whitespace found in object header b'2138' b'0'
# Superfluous whitespace found in object header b'2139' b'0'
# Superfluous whitespace found in object header b'2140' b'0'
# Superfluous whitespace found in object header b'2141' b'0'
# Superfluous whitespace found in object header b'2142' b'0'
# Superfluous whitespace found in object header b'2143' b'0'
# Superfluous whitespace found in object header b'2144' b'0'
# Superfluous whitespace found in object header b'2145' b'0'
# Superfluous whitespace found in object header b'2146' b'0'
# Superfluous whitespace found in object header b'2147' b'0'
# Superfluous whitespace found in object header b'2148' b'0'
# Superfluous whitespace found in object header b'2149' b'0'
# Superfluous whitespace found in object header b'2150' b'0'
# Superfluous whitespace found in object header b'2151' b'0'
# Superfluous whitespace found in object header b'2152' b'0'
# Superfluous whitespace found in object header b'2153' b'0'
# Superfluous whitespace found in object header b'2154' b'0'
# Superfluous whitespace found in object header b'2155' b'0'
# Superfluous whitespace found in object header b'2156' b'0'
# Superfluous whitespace found in object header b'2157' b'0'
# Superfluous whitespace found in object header b'2158' b'0'
# Superfluous whitespace found in object header b'2159' b'0'
# Superfluous whitespace found in object header b'2160' b'0'
# Superfluous whitespace found in object header b'2161' b'0'
# Superfluous whitespace found in object header b'2162' b'0'
# Superfluous whitespace found in object header b'2163' b'0'
# Superfluous whitespace found in object header b'2164' b'0'
# Superfluous whitespace found in object header b'2165' b'0'
# Superfluous whitespace found in object header b'2166' b'0'
# Superfluous whitespace found in object header b'2167' b'0'
# Superfluous whitespace found in object header b'2168' b'0'
# Superfluous whitespace found in object header b'2169' b'0'
# Superfluous whitespace found in object header b'2170' b'0'
# Superfluous whitespace found in object header b'2171' b'0'
# Superfluous whitespace found in object header b'2172' b'0'
# Superfluous whitespace found in object header b'2173' b'0'
# Superfluous whitespace found in object header b'2174' b'0'
# Superfluous whitespace found in object header b'2175' b'0'
# Superfluous whitespace found in object header b'2176' b'0'
# Superfluous whitespace found in object header b'2177' b'0'
# Superfluous whitespace found in object header b'2178' b'0'
# Superfluous whitespace found in object header b'2179' b'0'
# Superfluous whitespace found in object header b'2180' b'0'
# Superfluous whitespace found in object header b'2181' b'0'
# Superfluous whitespace found in object header b'2182' b'0'
# Superfluous whitespace found in object header b'2183' b'0'
# Superfluous whitespace found in object header b'2247' b'0'
# Superfluous whitespace found in object header b'2187' b'0'
# Superfluous whitespace found in object header b'2246' b'0'
# Superfluous whitespace found in object header b'2188' b'0'
# Superfluous whitespace found in object header b'2189' b'0'
# Superfluous whitespace found in object header b'2190' b'0'
# Superfluous whitespace found in object header b'2191' b'0'
# Superfluous whitespace found in object header b'2192' b'0'
# Superfluous whitespace found in object header b'2193' b'0'
# Superfluous whitespace found in object header b'2194' b'0'
# Superfluous whitespace found in object header b'2195' b'0'
# Superfluous whitespace found in object header b'2196' b'0'
# Superfluous whitespace found in object header b'2197' b'0'
# Superfluous whitespace found in object header b'2198' b'0'
# Superfluous whitespace found in object header b'2199' b'0'
# Superfluous whitespace found in object header b'2200' b'0'
# Superfluous whitespace found in object header b'2201' b'0'
# Superfluous whitespace found in object header b'2202' b'0'
# Superfluous whitespace found in object header b'2203' b'0'
# Superfluous whitespace found in object header b'2204' b'0'
# Superfluous whitespace found in object header b'2205' b'0'
# Superfluous whitespace found in object header b'2206' b'0'
# Superfluous whitespace found in object header b'2207' b'0'
# Superfluous whitespace found in object header b'2208' b'0'
# Superfluous whitespace found in object header b'2209' b'0'
# Superfluous whitespace found in object header b'2210' b'0'
# Superfluous whitespace found in object header b'2211' b'0'
# Superfluous whitespace found in object header b'2212' b'0'
# Superfluous whitespace found in object header b'2213' b'0'
# Superfluous whitespace found in object header b'2214' b'0'
# Superfluous whitespace found in object header b'2215' b'0'
# Superfluous whitespace found in object header b'2216' b'0'
# Superfluous whitespace found in object header b'2217' b'0'
# Superfluous whitespace found in object header b'2218' b'0'
# Superfluous whitespace found in object header b'2219' b'0'
# Superfluous whitespace found in object header b'2220' b'0'
# Superfluous whitespace found in object header b'2221' b'0'
# Superfluous whitespace found in object header b'2222' b'0'
# Superfluous whitespace found in object header b'2223' b'0'
# Superfluous whitespace found in object header b'2224' b'0'
# Superfluous whitespace found in object header b'2225' b'0'
# Superfluous whitespace found in object header b'2226' b'0'
# Superfluous whitespace found in object header b'2227' b'0'
# Superfluous whitespace found in object header b'2228' b'0'
# Superfluous whitespace found in object header b'2229' b'0'
# Superfluous whitespace found in object header b'2230' b'0'
# Superfluous whitespace found in object header b'2231' b'0'
# Superfluous whitespace found in object header b'2232' b'0'
# Superfluous whitespace found in object header b'2233' b'0'
# Superfluous whitespace found in object header b'2234' b'0'
# Superfluous whitespace found in object header b'2235' b'0'
# Superfluous whitespace found in object header b'2236' b'0'
# Superfluous whitespace found in object header b'2237' b'0'
# Superfluous whitespace found in object header b'2238' b'0'
# Superfluous whitespace found in object header b'2239' b'0'
# Superfluous whitespace found in object header b'2240' b'0'
# Superfluous whitespace found in object header b'2241' b'0'
# Superfluous whitespace found in object header b'2242' b'0'
# Superfluous whitespace found in object header b'2243' b'0'
# Superfluous whitespace found in object header b'2244' b'0'
# Superfluous whitespace found in object header b'2245' b'0'
# Superfluous whitespace found in object header b'2302' b'0'
# Superfluous whitespace found in object header b'2249' b'0'
# Superfluous whitespace found in object header b'2301' b'0'
# Superfluous whitespace found in object header b'2250' b'0'
# Superfluous whitespace found in object header b'2251' b'0'
# Superfluous whitespace found in object header b'2252' b'0'
# Superfluous whitespace found in object header b'2253' b'0'
# Superfluous whitespace found in object header b'2254' b'0'
# Superfluous whitespace found in object header b'2255' b'0'
# Superfluous whitespace found in object header b'2256' b'0'
# Superfluous whitespace found in object header b'2257' b'0'
# Superfluous whitespace found in object header b'2258' b'0'
# Superfluous whitespace found in object header b'2259' b'0'
# Superfluous whitespace found in object header b'2260' b'0'
# Superfluous whitespace found in object header b'2261' b'0'
# Superfluous whitespace found in object header b'2262' b'0'
# Superfluous whitespace found in object header b'2263' b'0'
# Superfluous whitespace found in object header b'2264' b'0'
# Superfluous whitespace found in object header b'2265' b'0'
# Superfluous whitespace found in object header b'2266' b'0'
# Superfluous whitespace found in object header b'2267' b'0'
# Superfluous whitespace found in object header b'2268' b'0'
# Superfluous whitespace found in object header b'2269' b'0'
# Superfluous whitespace found in object header b'2270' b'0'
# Superfluous whitespace found in object header b'2271' b'0'
# Superfluous whitespace found in object header b'2272' b'0'
# Superfluous whitespace found in object header b'2273' b'0'
# Superfluous whitespace found in object header b'2274' b'0'
# Superfluous whitespace found in object header b'2275' b'0'
# Superfluous whitespace found in object header b'2276' b'0'
# Superfluous whitespace found in object header b'2277' b'0'
# Superfluous whitespace found in object header b'2278' b'0'
# Superfluous whitespace found in object header b'2279' b'0'
# Superfluous whitespace found in object header b'2280' b'0'
# Superfluous whitespace found in object header b'2281' b'0'
# Superfluous whitespace found in object header b'2282' b'0'
# Superfluous whitespace found in object header b'2283' b'0'
# Superfluous whitespace found in object header b'2284' b'0'
# Superfluous whitespace found in object header b'2285' b'0'
# Superfluous whitespace found in object header b'2286' b'0'
# Superfluous whitespace found in object header b'2287' b'0'
# Superfluous whitespace found in object header b'2288' b'0'
# Superfluous whitespace found in object header b'2289' b'0'
# Superfluous whitespace found in object header b'2290' b'0'
# Superfluous whitespace found in object header b'2291' b'0'
# Superfluous whitespace found in object header b'2292' b'0'
# Superfluous whitespace found in object header b'2293' b'0'
# Superfluous whitespace found in object header b'2294' b'0'
# Superfluous whitespace found in object header b'2295' b'0'
# Superfluous whitespace found in object header b'2296' b'0'
# Superfluous whitespace found in object header b'2297' b'0'
# Superfluous whitespace found in object header b'2298' b'0'
# Superfluous whitespace found in object header b'2299' b'0'
# Superfluous whitespace found in object header b'2300' b'0'
# Superfluous whitespace found in object header b'2315' b'0'
# Superfluous whitespace found in object header b'2304' b'0'
# Superfluous whitespace found in object header b'2305' b'0'
# Superfluous whitespace found in object header b'2306' b'0'
# Superfluous whitespace found in object header b'2307' b'0'
# Superfluous whitespace found in object header b'2308' b'0'
# Superfluous whitespace found in object header b'2309' b'0'
# Superfluous whitespace found in object header b'2310' b'0'
# Superfluous whitespace found in object header b'2311' b'0'
# Superfluous whitespace found in object header b'2312' b'0'
# Superfluous whitespace found in object header b'2313' b'0'
# Superfluous whitespace found in object header b'2314' b'0'
# Superfluous whitespace found in object header b'2324' b'0'
# Superfluous whitespace found in object header b'2317' b'0'
# Superfluous whitespace found in object header b'2318' b'0'
# Superfluous whitespace found in object header b'2319' b'0'
# Superfluous whitespace found in object header b'2320' b'0'
# Superfluous whitespace found in object header b'2321' b'0'
# Superfluous whitespace found in object header b'2322' b'0'
# Superfluous whitespace found in object header b'2323' b'0'
# Superfluous whitespace found in object header b'2348' b'0'
# Superfluous whitespace found in object header b'2326' b'0'
# Superfluous whitespace found in object header b'2327' b'0'
# Superfluous whitespace found in object header b'2328' b'0'
# Superfluous whitespace found in object header b'2329' b'0'
# Superfluous whitespace found in object header b'2330' b'0'
# Superfluous whitespace found in object header b'2331' b'0'
# Superfluous whitespace found in object header b'2332' b'0'
# Superfluous whitespace found in object header b'2333' b'0'
# Superfluous whitespace found in object header b'2334' b'0'
# Superfluous whitespace found in object header b'2335' b'0'
# Superfluous whitespace found in object header b'2336' b'0'
# Superfluous whitespace found in object header b'2337' b'0'
# Superfluous whitespace found in object header b'2338' b'0'
# Superfluous whitespace found in object header b'2339' b'0'
# Superfluous whitespace found in object header b'2340' b'0'
# Superfluous whitespace found in object header b'2341' b'0'
# Superfluous whitespace found in object header b'2342' b'0'
# Superfluous whitespace found in object header b'2343' b'0'
# Superfluous whitespace found in object header b'2344' b'0'
# Superfluous whitespace found in object header b'2345' b'0'
# Superfluous whitespace found in object header b'2346' b'0'
# Superfluous whitespace found in object header b'2347' b'0'
# Superfluous whitespace found in object header b'2372' b'0'
# Superfluous whitespace found in object header b'2350' b'0'
# Superfluous whitespace found in object header b'2351' b'0'
# Superfluous whitespace found in object header b'2352' b'0'
# Superfluous whitespace found in object header b'2353' b'0'
# Superfluous whitespace found in object header b'2354' b'0'
# Superfluous whitespace found in object header b'2355' b'0'
# Superfluous whitespace found in object header b'2356' b'0'
# Superfluous whitespace found in object header b'2357' b'0'
# Superfluous whitespace found in object header b'2358' b'0'
# Superfluous whitespace found in object header b'2359' b'0'
# Superfluous whitespace found in object header b'2360' b'0'
# Superfluous whitespace found in object header b'2361' b'0'
# Superfluous whitespace found in object header b'2362' b'0'
# Superfluous whitespace found in object header b'2363' b'0'
# Superfluous whitespace found in object header b'2364' b'0'
# Superfluous whitespace found in object header b'2365' b'0'
# Superfluous whitespace found in object header b'2366' b'0'
# Superfluous whitespace found in object header b'2367' b'0'
# Superfluous whitespace found in object header b'2368' b'0'
# Superfluous whitespace found in object header b'2369' b'0'
# Superfluous whitespace found in object header b'2370' b'0'
# Superfluous whitespace found in object header b'2371' b'0'
# Superfluous whitespace found in object header b'2399' b'0'
# Superfluous whitespace found in object header b'2374' b'0'
# Superfluous whitespace found in object header b'2375' b'0'
# Superfluous whitespace found in object header b'2376' b'0'
# Superfluous whitespace found in object header b'2377' b'0'
# Superfluous whitespace found in object header b'2378' b'0'
# Superfluous whitespace found in object header b'2379' b'0'
# Superfluous whitespace found in object header b'2380' b'0'
# Superfluous whitespace found in object header b'2381' b'0'
# Superfluous whitespace found in object header b'2382' b'0'
# Superfluous whitespace found in object header b'2383' b'0'
# Superfluous whitespace found in object header b'2384' b'0'
# Superfluous whitespace found in object header b'2385' b'0'
# Superfluous whitespace found in object header b'2386' b'0'
# Superfluous whitespace found in object header b'2387' b'0'
# Superfluous whitespace found in object header b'2388' b'0'
# Superfluous whitespace found in object header b'2389' b'0'
# Superfluous whitespace found in object header b'2390' b'0'
# Superfluous whitespace found in object header b'2391' b'0'
# Superfluous whitespace found in object header b'2392' b'0'
# Superfluous whitespace found in object header b'2393' b'0'
# Superfluous whitespace found in object header b'2394' b'0'
# Superfluous whitespace found in object header b'2395' b'0'
# Superfluous whitespace found in object header b'2396' b'0'
# Superfluous whitespace found in object header b'2397' b'0'
# Superfluous whitespace found in object header b'2398' b'0'
# Superfluous whitespace found in object header b'2406' b'0'
# Superfluous whitespace found in object header b'2401' b'0'
# Superfluous whitespace found in object header b'2402' b'0'
# Superfluous whitespace found in object header b'2403' b'0'
# Superfluous whitespace found in object header b'2404' b'0'
# Superfluous whitespace found in object header b'2405' b'0'
# ran NER, saved page json
# Converted /media/alex/Data/agnes_data/onroerend_erfgoed/pdf/3039_OAOE336-001.pdf to html!
# generated and saved html
# updated config with latest id: 3039
# uploaded json/html to webserver
# indexing on webserver started
# done!
